# %%
# Load packages
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import os
import scipy as scp
import scipy.stats as scps
from datetime import datetime

# Load my own functions
import dnnregressor_train_eval_keras as dnnk
import make_data_wfpt as mdw

# %%
# Load data
data = pd.read_csv(os.getcwd() + '/data_storage/data_11000000_from_simulation_mix_09_12_18_18_20_50.csv')

# %%
# Some cleaning of the data
data = data[['v', 'a', 'w', 'rt', 'choice', 'nf_likelihood']]
data = data.loc[data['w'] > 0.1]
data = data.loc[data['w'] < 0.9]
data = data.loc[data['a'] > 0.5]

mini_data = data.loc[1:10000]


train_f, train_l, test_f, test_l = mdw.train_test_split_rt_choice(data = data,
                                                                  write_to_file = False,
                                                                  from_file = False,
                                                                  p_train = 0.8,
                                                                  backend = 'keras')
# Choice probabilities
# train_f, train_l, test_f, test_l = mdw.train_test_from_file_choice_probabilities(n_samples = 2500000,
#                                                             f_signature = '_choice_probabilities_analytic_',
#                                                                                 backend = 'keras')

# rt_choice
# train_f, train_l, test_f, test_l = mdw.train_test_from_file_rt_choice(n_samples = 11000000,
#                                                                       f_signature = '_from_simulation_mix_',
#                                                                       backend = 'keras')

# %%
# Make dnnk class (cpm for choice probability model)
cpm = dnnk.dnn_trainer()
cpm.data['train_features'] = train_f
cpm.data['train_labels'] = train_l
cpm.data['test_features'] = test_f
cpm.data['test_labels'] = test_l

# %%
# Make all parameters we can specify explicit
# Model parameters
cpm.model_params
# Out:
# {'input_shape': 3,
#  'output_shape': 1,
#  'output_activation': 'sigmoid',
#  'hidden_layers': [20, 20, 20, 20],
#  'hidden_activations': ['relu', 'relu', 'relu', 'relu'],
#  'l1_activation': [0.0, 0.0, 0.0, 0.0],
#  'l2_activation': [0.0, 0.0, 0.0, 0.0],
#  'l1_kernel': [0.0, 0.0, 0.0, 0.0],
#  'l2_kernel': [0.0, 0.0, 0.0, 0.0],
#  'optimizer': 'Nadam',
#  'loss': 'mse',
#  'metrics': ['mse']}

# %%
# Parameters governing training
cpm.train_params
# Out:
# {'callback_funs': ['ReduceLROnPlateau', 'EarlyStopping', 'ModelCheckpoint'],
#  'plateau_patience': 10,
#  'min_delta': 0.0001,
#  'early_stopping_patience': 15,
#  'callback_monitor': 'loss',
#  'min_learning_rate': 1e-07,
#  'red_coef_learning_rate': 0.1,
#  'ckpt_period': 10,
#  'ckpt_save_best_only': True,
#  'ckpt_save_weights_only': True,
#  'max_train_epochs': 2000,
#  'batch_size': 10000,
#  'warm_start': False,
#  'checkpoint': 'ckpt',
#  'model_cnt': 0}

# %%
# Parameters concerning data storage
cpm.data_params
# Out:
# {'data_type': 'choice_probabilities',
#  'model_directory': '/home/afengler/git_repos/nn_likelihoods/keras_models',
#  'checkpoint': 'ckpt',
#  'model_name': 'dnnregressor',
#  'data_type_signature': '_choice_probabilities_analytic_',
#  'timestamp': '09_16_18_21_23_13',
#  'training_data_size': 2500000}

# %%
# SPECIFYING META PARAMETERS THAT STAY CONSTANT DURING HYPERPARAMETER OPTIMIZATION

# Model params
cpm.model_params['output_activation'] = 'linear'
cpm.model_params['input_shape'] = 5

# Training params
# Meta
cpm.train_params['early_stopping_patience'] = 5
cpm.train_params['plateau_patience'] = 3
cpm.train_params['min_delta'] = 0.05
cpm.train_params['ckpt_period'] = 1
cpm.train_params['model_cnt'] = 0
cpm.train_params['max_train_epochs'] = 25

# Hyper
#cpm.train_params['l1_kernel']
cpm.model_params['hidden_layers'] = [5, 5, 5, 5]
#cpm.train_params['hidden_activations']
#cpm.train_params['l2_kernel'] = [0.5, 0.5, 0.5, 0.5]
#cpm.train_params['l2_activation'] = [0.5, 0.5, 0.5, 0.5]

# Data params
cpm.data_params['data_type'] = 'wfpt'
cpm.data_params['data_type_signature'] = '_choice_rt_'
cpm.data_params['training_data_size'] = 11000000

# Update timestamp
cpm.data_params['timestamp'] = datetime.now().strftime('%m_%d_%y_%H_%M_%S')

# %%
# Make model
# cpm.keras_model_generate(save_model = True)

# %%
# Train model
# cpm.run_training(save_history = True, 
#                  warm_start = False)

# %%
# Hyperparameter training loop:

# Runs: 
num_runs = 25
cnt = 0
max_layers = 5
layer_sizes = [10, 20, 50]
batch_sizes = [1000, 10000, 50000]
regularization_sizes = [0.05, 0.1, 0.2]

# Update model directory to make sure we collect all our models from this hyperparameter optimization run in the same place
cpm.data_params['model_directory'] =  '/home/afengler/git_repos/nn_likelihoods/keras_models/'
cpm.data_params['model_name'] = 'dnnregressor_wftp_hyp_opt'
cpm.train_params['model_cnt'] = 0

histories = []

while cnt < num_runs:
    cnt += 1
    
    # Sample # layers 
    num_layers = np.random.choice(np.arange(1, max_layers, 1))
    
    # Layer sizes
    layers = []
    activations = []
    regularizers_l1 = []
    regularizers_l2 = []
    regularizer = np.random.choice(['l1', 'l2'])
    regularizer_size = np.random.choice(regularization_sizes)
    
    for i in range(0, num_layers, 1):
        layers.append(np.random.choice(layer_sizes))
        activations.append('relu')
        if regularizer == 'l1':
            regularizers_l1.append(regularizer_size)
            regularizers_l2.append(0.0)
        else:
            regularizers_l1.append(0.0)
            regularizers_l2.append(regularizer_size)
        
    # Batch size
    batch_size = np.random.choice(batch_sizes)
    
    # Update relevant model parameters
    cpm.train_params['batch_size'] = batch_size
    print('batch_size: ', batch_size)
    cpm.model_params['hidden_layers'] = layers
    print('layers: ', layers)
    cpm.model_params['hidden_activations'] = activations
    print('hidden_activations:', activations)
#     cpm.model_params['l1_activation'] = regularizers_l1
#     print('l1_activatons: ', regularizers_l1)
#     cpm.model_params['l2_activation'] = regularizers
#     print('l2_activations:', regularizers_l2)
    cpm.model_params['l1_kernel'] = regularizers_l1
    print('l1_kernel: ', regularizers_l1)
    cpm.model_params['l2_kernel'] = regularizers_l2
    print('l2_kernel: ', regularizers_l2)
    
    # Make new timestamp
    #cpm.data_params['timestamp'] = datetime.now().strftime('%m_%d_%y_%H_%M_%S')
    
    # Make model
    cpm.keras_model_generate(save_model = True)
    
    # Train model
    cpm.run_training(save_history = True, 
                    warm_start = False) # Note that this increments model count automatically !
    
#     histories[-1]['model_cnt'] = cpm.train_params['model_cnt']
#     histories[-1]['num_layers'] = num_layers
#     histories[-1]['size_layers'] = str(layers)
#     histories[-1]['activations'] = str(activations) 
#     histories[-1]['batch_size'] = batch_size
    
    print(cnt)
    
# histories = pd.concat(histories)
# histories['optimizer'] = cpm.model_params['optimizer']
# histories['timestamp'] = datetime.now().strftime('%m_%d_%y_%H_%M_%S')
# histories.to_csv(cpm.data_params['model_directory'] + cpm.data_params['model_name'] + '_choice_rt_' +\
#                  cpm.data_params['timestamp'] + '/hyp_opt_histories.csv')
# Out:
# batch_size:  10000
# layers:  [20]
# hidden_activations: ['relu']
# l1_kernel:  [0.2]
# l2_kernel:  [0.0]
# Train on 6070763 samples, validate on 1517244 samples
# Epoch 1/25
# 6070763/6070763 [==============================] - 178s 29us/step - loss: 18.8992 - mean_squared_error: 16.0375 - val_loss: 17.4860 - val_mean_squared_error: 14.3706
#
# Epoch 00001: val_loss improved from inf to 17.48602, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-0-01
# Epoch 2/25
# 6070763/6070763 [==============================] - 189s 31us/step - loss: 16.5867 - mean_squared_error: 13.3878 - val_loss: 16.1290 - val_mean_squared_error: 12.8795
#
# Epoch 00002: val_loss improved from 17.48602 to 16.12904, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-0-02
# Epoch 3/25
# 6070763/6070763 [==============================] - 184s 30us/step - loss: 15.8765 - mean_squared_error: 12.6150 - val_loss: 15.5689 - val_mean_squared_error: 12.3205
#
# Epoch 00003: val_loss improved from 16.12904 to 15.56889, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-0-03
# Epoch 4/25
# 6070763/6070763 [==============================] - 190s 31us/step - loss: 15.4778 - mean_squared_error: 12.2293 - val_loss: 15.2825 - val_mean_squared_error: 12.0280
#
# Epoch 00004: val_loss improved from 15.56889 to 15.28255, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-0-04
# Epoch 5/25
# 6070763/6070763 [==============================] - 189s 31us/step - loss: 15.1870 - mean_squared_error: 11.9470 - val_loss: 15.0297 - val_mean_squared_error: 11.8126
#
# Epoch 00005: val_loss improved from 15.28255 to 15.02971, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-0-05
# Epoch 6/25
# 6070763/6070763 [==============================] - 190s 31us/step - loss: 14.9595 - mean_squared_error: 11.7381 - val_loss: 14.8363 - val_mean_squared_error: 11.6071
#
# Epoch 00006: val_loss improved from 15.02971 to 14.83627, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-0-06
# Epoch 7/25
# 6070763/6070763 [==============================] - 189s 31us/step - loss: 14.7724 - mean_squared_error: 11.5523 - val_loss: 14.6220 - val_mean_squared_error: 11.4048
#
# Epoch 00007: val_loss improved from 14.83627 to 14.62203, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-0-07
# Epoch 8/25
# 6070763/6070763 [==============================] - 189s 31us/step - loss: 14.6180 - mean_squared_error: 11.4009 - val_loss: 14.7430 - val_mean_squared_error: 11.5173
#
# Epoch 00008: val_loss did not improve from 14.62203
# Epoch 9/25
# 6070763/6070763 [==============================] - 189s 31us/step - loss: 14.4823 - mean_squared_error: 11.2725 - val_loss: 14.3479 - val_mean_squared_error: 11.1430
#
# Epoch 00009: val_loss improved from 14.62203 to 14.34793, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-0-09
# Epoch 10/25
# 6070763/6070763 [==============================] - 183s 30us/step - loss: 14.3657 - mean_squared_error: 11.1628 - val_loss: 14.2941 - val_mean_squared_error: 11.0940
#
# Epoch 00010: val_loss improved from 14.34793 to 14.29405, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-0-10
# Epoch 11/25
# 6070763/6070763 [==============================] - 176s 29us/step - loss: 14.2629 - mean_squared_error: 11.0578 - val_loss: 14.1783 - val_mean_squared_error: 10.9795
#
# Epoch 00011: val_loss improved from 14.29405 to 14.17831, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-0-11
# Epoch 12/25
# 6070763/6070763 [==============================] - 172s 28us/step - loss: 14.1637 - mean_squared_error: 10.9622 - val_loss: 14.7396 - val_mean_squared_error: 11.5242
#
# Epoch 00012: val_loss did not improve from 14.17831
# Epoch 13/25
# 6070763/6070763 [==============================] - 176s 29us/step - loss: 14.0817 - mean_squared_error: 10.8884 - val_loss: 14.5348 - val_mean_squared_error: 11.3360
#
# Epoch 00013: val_loss did not improve from 14.17831
# Epoch 14/25
# 6070763/6070763 [==============================] - 166s 27us/step - loss: 14.0032 - mean_squared_error: 10.8146 - val_loss: 14.2332 - val_mean_squared_error: 11.0248
#
# Epoch 00014: val_loss did not improve from 14.17831
# Epoch 15/25
# 6070763/6070763 [==============================] - 165s 27us/step - loss: 13.9303 - mean_squared_error: 10.7466 - val_loss: 13.8661 - val_mean_squared_error: 10.6972
#
# Epoch 00015: val_loss improved from 14.17831 to 13.86612, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-0-15
# Epoch 16/25
# 6070763/6070763 [==============================] - 165s 27us/step - loss: 13.8637 - mean_squared_error: 10.6875 - val_loss: 14.3556 - val_mean_squared_error: 11.1849
#
# Epoch 00016: val_loss did not improve from 13.86612
# Epoch 17/25
# 6070763/6070763 [==============================] - 165s 27us/step - loss: 13.8021 - mean_squared_error: 10.6295 - val_loss: 13.6696 - val_mean_squared_error: 10.5067
#
# Epoch 00017: val_loss improved from 13.86612 to 13.66959, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-0-17
# Epoch 18/25
# 6070763/6070763 [==============================] - 165s 27us/step - loss: 13.7453 - mean_squared_error: 10.5789 - val_loss: 14.1795 - val_mean_squared_error: 11.0180
#
# Epoch 00018: val_loss did not improve from 13.66959
# Epoch 19/25
# 6070763/6070763 [==============================] - 166s 27us/step - loss: 13.6904 - mean_squared_error: 10.5292 - val_loss: 13.7537 - val_mean_squared_error: 10.6021
#
# Epoch 00019: val_loss did not improve from 13.66959
# Epoch 20/25
# 6070763/6070763 [==============================] - 166s 27us/step - loss: 13.6411 - mean_squared_error: 10.4865 - val_loss: 13.5887 - val_mean_squared_error: 10.4266
#
# Epoch 00020: val_loss improved from 13.66959 to 13.58865, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-0-20
# Epoch 21/25
# 6070763/6070763 [==============================] - 166s 27us/step - loss: 13.5926 - mean_squared_error: 10.4402 - val_loss: 13.5183 - val_mean_squared_error: 10.3521
#
# Epoch 00021: val_loss improved from 13.58865 to 13.51831, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-0-21
# Epoch 22/25
# 6070763/6070763 [==============================] - 165s 27us/step - loss: 13.5457 - mean_squared_error: 10.3986 - val_loss: 16.0604 - val_mean_squared_error: 12.9082
#
# Epoch 00022: val_loss did not improve from 13.51831
# Epoch 23/25
# 6070763/6070763 [==============================] - 166s 27us/step - loss: 13.5006 - mean_squared_error: 10.3578 - val_loss: 13.3732 - val_mean_squared_error: 10.2422
#
# Epoch 00023: val_loss improved from 13.51831 to 13.37324, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-0-23
# Epoch 24/25
# 6070763/6070763 [==============================] - 165s 27us/step - loss: 13.4609 - mean_squared_error: 10.3232 - val_loss: 13.7569 - val_mean_squared_error: 10.6166
#
# Epoch 00024: val_loss did not improve from 13.37324
# Epoch 25/25
# 6070763/6070763 [==============================] - 165s 27us/step - loss: 13.4252 - mean_squared_error: 10.2953 - val_loss: 13.3026 - val_mean_squared_error: 10.1767
#
# Epoch 00025: val_loss improved from 13.37324 to 13.30262, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-0-25
# 1
# batch_size:  50000
# layers:  [10]
# hidden_activations: ['relu']
# l1_kernel:  [0.0]
# l2_kernel:  [0.05]
# Train on 6070763 samples, validate on 1517244 samples
# Epoch 1/25
# 6070763/6070763 [==============================] - 166s 27us/step - loss: 15.8697 - mean_squared_error: 14.3469 - val_loss: 14.2002 - val_mean_squared_error: 12.6542
#
# Epoch 00001: val_loss improved from inf to 14.20019, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-1-01
# Epoch 2/25
# 6070763/6070763 [==============================] - 165s 27us/step - loss: 13.7125 - mean_squared_error: 12.1571 - val_loss: 13.7114 - val_mean_squared_error: 12.1248
#
# Epoch 00002: val_loss improved from 14.20019 to 13.71144, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-1-02
# Epoch 3/25
# 6070763/6070763 [==============================] - 165s 27us/step - loss: 12.9517 - mean_squared_error: 11.3584 - val_loss: 12.6801 - val_mean_squared_error: 11.0783
#
# Epoch 00003: val_loss improved from 13.71144 to 12.68009, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-1-03
# Epoch 4/25
# 6070763/6070763 [==============================] - 165s 27us/step - loss: 12.5187 - mean_squared_error: 10.9152 - val_loss: 12.7215 - val_mean_squared_error: 11.1061
#
# Epoch 00004: val_loss did not improve from 12.68009
# Epoch 5/25
# 6070763/6070763 [==============================] - 165s 27us/step - loss: 12.2213 - mean_squared_error: 10.6203 - val_loss: 12.4030 - val_mean_squared_error: 10.8167
#
# Epoch 00005: val_loss improved from 12.68009 to 12.40301, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-1-05
# Epoch 6/25
# 6070763/6070763 [==============================] - 165s 27us/step - loss: 12.0135 - mean_squared_error: 10.4206 - val_loss: 11.6598 - val_mean_squared_error: 10.0905
#
# Epoch 00006: val_loss improved from 12.40301 to 11.65983, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-1-06
# Epoch 7/25
# 6070763/6070763 [==============================] - 166s 27us/step - loss: 11.8396 - mean_squared_error: 10.2639 - val_loss: 11.5067 - val_mean_squared_error: 9.9244
#
# Epoch 00007: val_loss improved from 11.65983 to 11.50672, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-1-07
# Epoch 8/25
# 6070763/6070763 [==============================] - 166s 27us/step - loss: 11.7051 - mean_squared_error: 10.1271 - val_loss: 11.5863 - val_mean_squared_error: 10.0188
#
# Epoch 00008: val_loss did not improve from 11.50672
# Epoch 9/25
# 6070763/6070763 [==============================] - 166s 27us/step - loss: 11.5890 - mean_squared_error: 10.0203 - val_loss: 11.7225 - val_mean_squared_error: 10.1645
#
# Epoch 00009: val_loss did not improve from 11.50672
# Epoch 10/25
# 6070763/6070763 [==============================] - 166s 27us/step - loss: 11.4874 - mean_squared_error: 9.9236 - val_loss: 11.5264 - val_mean_squared_error: 9.9731
#
# Epoch 00010: val_loss did not improve from 11.50672
# Epoch 11/25
# 6070763/6070763 [==============================] - 165s 27us/step - loss: 11.4022 - mean_squared_error: 9.8467 - val_loss: 11.3203 - val_mean_squared_error: 9.7617
#
# Epoch 00011: val_loss improved from 11.50672 to 11.32030, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-1-11
# Epoch 12/25
# 6070763/6070763 [==============================] - 165s 27us/step - loss: 11.3258 - mean_squared_error: 9.7724 - val_loss: 11.2692 - val_mean_squared_error: 9.7177
#
# Epoch 00012: val_loss improved from 11.32030 to 11.26917, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-1-12
# Epoch 13/25
# 6070763/6070763 [==============================] - 166s 27us/step - loss: 11.2585 - mean_squared_error: 9.7098 - val_loss: 11.0760 - val_mean_squared_error: 9.5362
#
# Epoch 00013: val_loss improved from 11.26917 to 11.07596, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-1-13
# Epoch 14/25
# 6070763/6070763 [==============================] - 165s 27us/step - loss: 11.1950 - mean_squared_error: 9.6537 - val_loss: 11.6139 - val_mean_squared_error: 10.0806
#
# Epoch 00014: val_loss did not improve from 11.07596
# Epoch 15/25
# 6070763/6070763 [==============================] - 166s 27us/step - loss: 11.1448 - mean_squared_error: 9.6100 - val_loss: 11.1033 - val_mean_squared_error: 9.5652
#
# Epoch 00015: val_loss did not improve from 11.07596
# Epoch 16/25
# 6070763/6070763 [==============================] - 165s 27us/step - loss: 11.0888 - mean_squared_error: 9.5520 - val_loss: 10.7352 - val_mean_squared_error: 9.2111
#
# Epoch 00016: val_loss improved from 11.07596 to 10.73522, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-1-16
# Epoch 17/25
# 6070763/6070763 [==============================] - 166s 27us/step - loss: 11.0411 - mean_squared_error: 9.5102 - val_loss: 11.3305 - val_mean_squared_error: 9.8138
#
# Epoch 00017: val_loss did not improve from 10.73522
# Epoch 18/25
# 6070763/6070763 [==============================] - 166s 27us/step - loss: 10.9989 - mean_squared_error: 9.4755 - val_loss: 10.8196 - val_mean_squared_error: 9.3114
#
# Epoch 00018: val_loss did not improve from 10.73522
# Epoch 19/25
# 6070763/6070763 [==============================] - 166s 27us/step - loss: 10.9592 - mean_squared_error: 9.4461 - val_loss: 10.8834 - val_mean_squared_error: 9.3421
#
# Epoch 00019: val_loss did not improve from 10.73522
# Epoch 20/25
# 6070763/6070763 [==============================] - 166s 27us/step - loss: 10.9163 - mean_squared_error: 9.3954 - val_loss: 10.7663 - val_mean_squared_error: 9.2468
#
# Epoch 00020: val_loss did not improve from 10.73522
# Epoch 21/25
# 6070763/6070763 [==============================] - 166s 27us/step - loss: 10.8826 - mean_squared_error: 9.3708 - val_loss: 10.4224 - val_mean_squared_error: 8.9148
#
# Epoch 00021: val_loss improved from 10.73522 to 10.42236, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-1-21
# Epoch 22/25
# 6070763/6070763 [==============================] - 166s 27us/step - loss: 10.8556 - mean_squared_error: 9.3476 - val_loss: 10.6535 - val_mean_squared_error: 9.1328
#
# Epoch 00022: val_loss did not improve from 10.42236
# Epoch 23/25
# 6070763/6070763 [==============================] - 166s 27us/step - loss: 10.8241 - mean_squared_error: 9.3177 - val_loss: 10.7833 - val_mean_squared_error: 9.2840
#
# Epoch 00023: val_loss did not improve from 10.42236
# Epoch 24/25
# 6070763/6070763 [==============================] - 166s 27us/step - loss: 10.7950 - mean_squared_error: 9.2932 - val_loss: 11.0885 - val_mean_squared_error: 9.5869
#
# Epoch 00024: val_loss did not improve from 10.42236
# Epoch 25/25
# 6070763/6070763 [==============================] - 166s 27us/step - loss: 10.7651 - mean_squared_error: 9.2666 - val_loss: 10.5811 - val_mean_squared_error: 9.0790
#
# Epoch 00025: val_loss did not improve from 10.42236
# 2
# batch_size:  1000
# layers:  [20, 50, 50]
# hidden_activations: ['relu', 'relu', 'relu']
# l1_kernel:  [0.2, 0.2, 0.2]
# l2_kernel:  [0.0, 0.0, 0.0]
# Train on 6070763 samples, validate on 1517244 samples
# Epoch 1/25
# 6070763/6070763 [==============================] - 220s 36us/step - loss: 11.5408 - mean_squared_error: 6.3905 - val_loss: 9.6107 - val_mean_squared_error: 4.7586
#
# Epoch 00001: val_loss improved from inf to 9.61067, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-2-01
# Epoch 2/25
# 6070763/6070763 [==============================] - 219s 36us/step - loss: 10.2220 - mean_squared_error: 5.5630 - val_loss: 9.0873 - val_mean_squared_error: 4.6016
#
# Epoch 00002: val_loss improved from 9.61067 to 9.08730, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-2-02
# Epoch 3/25
# 6070763/6070763 [==============================] - 220s 36us/step - loss: 9.9685 - mean_squared_error: 5.5766 - val_loss: 9.2782 - val_mean_squared_error: 4.8875
#
# Epoch 00003: val_loss did not improve from 9.08730
# Epoch 4/25
# 6070763/6070763 [==============================] - 220s 36us/step - loss: 9.8436 - mean_squared_error: 5.5766 - val_loss: 9.2426 - val_mean_squared_error: 4.9587
#
# Epoch 00004: val_loss did not improve from 9.08730
# Epoch 5/25
# 6070763/6070763 [==============================] - 220s 36us/step - loss: 9.7042 - mean_squared_error: 5.4560 - val_loss: 8.9131 - val_mean_squared_error: 4.5993
#
# Epoch 00005: val_loss improved from 9.08730 to 8.91309, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-2-05
# Epoch 6/25
# 6070763/6070763 [==============================] - 219s 36us/step - loss: 9.5752 - mean_squared_error: 5.3441 - val_loss: 9.0747 - val_mean_squared_error: 4.9125
#
# Epoch 00006: val_loss did not improve from 8.91309
# Epoch 7/25
# 6070763/6070763 [==============================] - 220s 36us/step - loss: 9.4592 - mean_squared_error: 5.3191 - val_loss: 8.2777 - val_mean_squared_error: 4.1757
#
# Epoch 00007: val_loss improved from 8.91309 to 8.27768, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-2-07
# Epoch 8/25
# 6070763/6070763 [==============================] - 220s 36us/step - loss: 9.4137 - mean_squared_error: 5.3221 - val_loss: 12.2924 - val_mean_squared_error: 8.1939
#
# Epoch 00008: val_loss did not improve from 8.27768
# Epoch 9/25
# 6070763/6070763 [==============================] - 220s 36us/step - loss: 9.4016 - mean_squared_error: 5.3553 - val_loss: 11.4267 - val_mean_squared_error: 7.3658
#
# Epoch 00009: val_loss did not improve from 8.27768
# Epoch 10/25
# 6070763/6070763 [==============================] - 220s 36us/step - loss: 9.3392 - mean_squared_error: 5.3219 - val_loss: 8.8050 - val_mean_squared_error: 4.8677
#
# Epoch 00010: val_loss did not improve from 8.27768
# Epoch 11/25
# 6070763/6070763 [==============================] - 220s 36us/step - loss: 9.3387 - mean_squared_error: 5.3608 - val_loss: 9.2031 - val_mean_squared_error: 5.2287
#
# Epoch 00011: val_loss did not improve from 8.27768
# Epoch 12/25
# 6070763/6070763 [==============================] - 221s 36us/step - loss: 9.2735 - mean_squared_error: 5.3465 - val_loss: 8.4840 - val_mean_squared_error: 4.6519
#
# Epoch 00012: val_loss did not improve from 8.27768
# Epoch 13/25
# 6070763/6070763 [==============================] - 220s 36us/step - loss: 9.2033 - mean_squared_error: 5.3318 - val_loss: 10.3448 - val_mean_squared_error: 6.5115
#
# Epoch 00013: val_loss did not improve from 8.27768
# Epoch 14/25
# 6070763/6070763 [==============================] - 220s 36us/step - loss: 9.1962 - mean_squared_error: 5.3409 - val_loss: 10.2105 - val_mean_squared_error: 6.3423
#
# Epoch 00014: val_loss did not improve from 8.27768
# Epoch 15/25
# 6070763/6070763 [==============================] - 220s 36us/step - loss: 9.2181 - mean_squared_error: 5.3626 - val_loss: 11.6320 - val_mean_squared_error: 7.8502
#
# Epoch 00015: val_loss did not improve from 8.27768
# Epoch 16/25
# 6070763/6070763 [==============================] - 220s 36us/step - loss: 9.1972 - mean_squared_error: 5.3777 - val_loss: 10.0730 - val_mean_squared_error: 6.2882
#
# Epoch 00016: val_loss did not improve from 8.27768
# Epoch 17/25
# 6070763/6070763 [==============================] - 220s 36us/step - loss: 9.1956 - mean_squared_error: 5.3639 - val_loss: 9.3600 - val_mean_squared_error: 5.5191
#
# Epoch 00017: val_loss did not improve from 8.27768
# Epoch 18/25
# 6070763/6070763 [==============================] - 221s 36us/step - loss: 9.1959 - mean_squared_error: 5.3862 - val_loss: 8.2336 - val_mean_squared_error: 4.4457
#
# Epoch 00018: val_loss improved from 8.27768 to 8.23358, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-2-18
# Epoch 00018: early stopping
# 3
# batch_size:  10000
# layers:  [50, 50]
# hidden_activations: ['relu', 'relu']
# l1_kernel:  [0.05, 0.05]
# l2_kernel:  [0.0, 0.0]
# Train on 6070763 samples, validate on 1517244 samples
# Epoch 1/25
# 6070763/6070763 [==============================] - 195s 32us/step - loss: 7.0707 - mean_squared_error: 3.7923 - val_loss: 5.9088 - val_mean_squared_error: 3.1351
#
# Epoch 00001: val_loss improved from inf to 5.90878, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-3-01
# Epoch 2/25
# 6070763/6070763 [==============================] - 195s 32us/step - loss: 5.5619 - mean_squared_error: 2.9071 - val_loss: 8.0988 - val_mean_squared_error: 5.6167
#
# Epoch 00002: val_loss did not improve from 5.90878
# Epoch 3/25
# 6070763/6070763 [==============================] - 195s 32us/step - loss: 5.3003 - mean_squared_error: 2.8746 - val_loss: 4.7002 - val_mean_squared_error: 2.3538
#
# Epoch 00003: val_loss improved from 5.90878 to 4.70016, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-3-03
# Epoch 4/25
# 6070763/6070763 [==============================] - 195s 32us/step - loss: 5.1881 - mean_squared_error: 2.8597 - val_loss: 4.6874 - val_mean_squared_error: 2.4083
#
# Epoch 00004: val_loss improved from 4.70016 to 4.68743, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-3-04
# Epoch 5/25
# 6070763/6070763 [==============================] - 195s 32us/step - loss: 5.1257 - mean_squared_error: 2.8627 - val_loss: 4.7542 - val_mean_squared_error: 2.4939
#
# Epoch 00005: val_loss did not improve from 4.68743
# Epoch 6/25
# 6070763/6070763 [==============================] - 195s 32us/step - loss: 5.0789 - mean_squared_error: 2.8646 - val_loss: 4.6261 - val_mean_squared_error: 2.4512
#
# Epoch 00006: val_loss improved from 4.68743 to 4.62606, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-3-06
# Epoch 7/25
# 6070763/6070763 [==============================] - 195s 32us/step - loss: 5.0528 - mean_squared_error: 2.8716 - val_loss: 4.8985 - val_mean_squared_error: 2.7151
#
# Epoch 00007: val_loss did not improve from 4.62606
# Epoch 8/25
# 6070763/6070763 [==============================] - 195s 32us/step - loss: 5.0172 - mean_squared_error: 2.8628 - val_loss: 4.9353 - val_mean_squared_error: 2.7706
#
# Epoch 00008: val_loss did not improve from 4.62606
# Epoch 9/25
# 6070763/6070763 [==============================] - 195s 32us/step - loss: 5.0088 - mean_squared_error: 2.8682 - val_loss: 4.7251 - val_mean_squared_error: 2.5944
#
# Epoch 00009: val_loss did not improve from 4.62606
# Epoch 10/25
# 6070763/6070763 [==============================] - 195s 32us/step - loss: 5.0077 - mean_squared_error: 2.8836 - val_loss: 8.1759 - val_mean_squared_error: 6.0286
#
# Epoch 00010: val_loss did not improve from 4.62606
# Epoch 11/25
# 6070763/6070763 [==============================] - 194s 32us/step - loss: 5.0040 - mean_squared_error: 2.8792 - val_loss: 4.4085 - val_mean_squared_error: 2.3243
#
# Epoch 00011: val_loss improved from 4.62606 to 4.40851, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-3-11
# Epoch 12/25
# 6070763/6070763 [==============================] - 194s 32us/step - loss: 4.9894 - mean_squared_error: 2.8797 - val_loss: 4.5506 - val_mean_squared_error: 2.4474
#
# Epoch 00012: val_loss did not improve from 4.40851
# Epoch 13/25
# 6070763/6070763 [==============================] - 195s 32us/step - loss: 4.9956 - mean_squared_error: 2.8960 - val_loss: 4.3462 - val_mean_squared_error: 2.2184
#
# Epoch 00013: val_loss improved from 4.40851 to 4.34616, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-3-13
# Epoch 14/25
# 6070763/6070763 [==============================] - 195s 32us/step - loss: 4.9805 - mean_squared_error: 2.8921 - val_loss: 5.7155 - val_mean_squared_error: 3.6217
#
# Epoch 00014: val_loss did not improve from 4.34616
# Epoch 15/25
# 6070763/6070763 [==============================] - 195s 32us/step - loss: 4.9738 - mean_squared_error: 2.8902 - val_loss: 4.3582 - val_mean_squared_error: 2.2632
#
# Epoch 00015: val_loss did not improve from 4.34616
# Epoch 16/25
# 6070763/6070763 [==============================] - 195s 32us/step - loss: 5.0016 - mean_squared_error: 2.9177 - val_loss: 5.2632 - val_mean_squared_error: 3.1546
#
# Epoch 00016: val_loss did not improve from 4.34616
# Epoch 17/25
# 6070763/6070763 [==============================] - 195s 32us/step - loss: 4.9974 - mean_squared_error: 2.9035 - val_loss: 5.0620 - val_mean_squared_error: 2.9702
#
# Epoch 00017: val_loss did not improve from 4.34616
# Epoch 00017: early stopping
# 4
# batch_size:  1000
# layers:  [50]
# hidden_activations: ['relu']
# l1_kernel:  [0.1]
# l2_kernel:  [0.0]
# Train on 6070763 samples, validate on 1517244 samples
# Epoch 1/25
# 6070763/6070763 [==============================] - 170s 28us/step - loss: 16.1515 - mean_squared_error: 13.4500 - val_loss: 14.2081 - val_mean_squared_error: 11.2047
#
# Epoch 00001: val_loss improved from inf to 14.20811, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-4-01
# Epoch 2/25
# 6070763/6070763 [==============================] - 169s 28us/step - loss: 13.8440 - mean_squared_error: 10.8537 - val_loss: 13.6237 - val_mean_squared_error: 10.6879
#
# Epoch 00002: val_loss improved from 14.20811 to 13.62369, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-4-02
# Epoch 3/25
# 6070763/6070763 [==============================] - 170s 28us/step - loss: 13.2946 - mean_squared_error: 10.3533 - val_loss: 13.0028 - val_mean_squared_error: 10.0975
#
# Epoch 00003: val_loss improved from 13.62369 to 13.00283, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-4-03
# Epoch 4/25
# 6070763/6070763 [==============================] - 169s 28us/step - loss: 12.9723 - mean_squared_error: 10.0562 - val_loss: 12.7952 - val_mean_squared_error: 9.8735
#
# Epoch 00004: val_loss improved from 13.00283 to 12.79516, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-4-04
# Epoch 5/25
# 6070763/6070763 [==============================] - 170s 28us/step - loss: 12.7454 - mean_squared_error: 9.8316 - val_loss: 12.6091 - val_mean_squared_error: 9.7048
#
# Epoch 00005: val_loss improved from 12.79516 to 12.60910, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-4-05
# Epoch 6/25
# 6070763/6070763 [==============================] - 170s 28us/step - loss: 12.5801 - mean_squared_error: 9.6740 - val_loss: 12.4865 - val_mean_squared_error: 9.5857
#
# Epoch 00006: val_loss improved from 12.60910 to 12.48654, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-4-06
# Epoch 7/25
# 6070763/6070763 [==============================] - 170s 28us/step - loss: 12.4409 - mean_squared_error: 9.5299 - val_loss: 12.2472 - val_mean_squared_error: 9.3500
#
# Epoch 00007: val_loss improved from 12.48654 to 12.24720, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-4-07
# Epoch 8/25
# 6070763/6070763 [==============================] - 170s 28us/step - loss: 12.3200 - mean_squared_error: 9.4151 - val_loss: 12.2168 - val_mean_squared_error: 9.3130
#
# Epoch 00008: val_loss improved from 12.24720 to 12.21679, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-4-08
# Epoch 9/25
# 6070763/6070763 [==============================] - 170s 28us/step - loss: 12.2259 - mean_squared_error: 9.3177 - val_loss: 11.9473 - val_mean_squared_error: 9.0458
#
# Epoch 00009: val_loss improved from 12.21679 to 11.94725, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-4-09
# Epoch 10/25
# 6070763/6070763 [==============================] - 170s 28us/step - loss: 12.1346 - mean_squared_error: 9.2278 - val_loss: 11.9954 - val_mean_squared_error: 9.0743
#
# Epoch 00010: val_loss did not improve from 11.94725
# Epoch 11/25
# 6070763/6070763 [==============================] - 170s 28us/step - loss: 12.0564 - mean_squared_error: 9.1450 - val_loss: 11.8653 - val_mean_squared_error: 8.9463
#
# Epoch 00011: val_loss improved from 11.94725 to 11.86529, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-4-11
# Epoch 12/25
# 6070763/6070763 [==============================] - 170s 28us/step - loss: 11.9877 - mean_squared_error: 9.0747 - val_loss: 11.7607 - val_mean_squared_error: 8.8640
#
# Epoch 00012: val_loss improved from 11.86529 to 11.76072, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-4-12
# Epoch 13/25
# 6070763/6070763 [==============================] - 170s 28us/step - loss: 11.9178 - mean_squared_error: 9.0066 - val_loss: 11.9202 - val_mean_squared_error: 9.0084
#
# Epoch 00013: val_loss did not improve from 11.76072
# Epoch 14/25
# 6070763/6070763 [==============================] - 170s 28us/step - loss: 11.8710 - mean_squared_error: 8.9537 - val_loss: 11.8249 - val_mean_squared_error: 8.9027
#
# Epoch 00014: val_loss did not improve from 11.76072
# Epoch 15/25
# 6070763/6070763 [==============================] - 170s 28us/step - loss: 11.8051 - mean_squared_error: 8.8891 - val_loss: 11.7987 - val_mean_squared_error: 8.8764
#
# Epoch 00015: val_loss did not improve from 11.76072
# Epoch 16/25
# 6070763/6070763 [==============================] - 171s 28us/step - loss: 11.7660 - mean_squared_error: 8.8483 - val_loss: 11.7846 - val_mean_squared_error: 8.8759
#
# Epoch 00016: val_loss did not improve from 11.76072
# Epoch 17/25
# 6070763/6070763 [==============================] - 170s 28us/step - loss: 11.7505 - mean_squared_error: 8.8653 - val_loss: 12.4212 - val_mean_squared_error: 9.6153
#
# Epoch 00017: val_loss did not improve from 11.76072
# Epoch 18/25
# 6070763/6070763 [==============================] - 171s 28us/step - loss: 11.7686 - mean_squared_error: 8.9669 - val_loss: 11.8016 - val_mean_squared_error: 8.9645
#
# Epoch 00018: val_loss did not improve from 11.76072
# Epoch 19/25
# 6070763/6070763 [==============================] - 170s 28us/step - loss: 11.7156 - mean_squared_error: 8.8779 - val_loss: 11.7127 - val_mean_squared_error: 8.8599
#
# Epoch 00019: val_loss improved from 11.76072 to 11.71272, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-4-19
# Epoch 20/25
# 6070763/6070763 [==============================] - 170s 28us/step - loss: 11.6625 - mean_squared_error: 8.8066 - val_loss: 12.0183 - val_mean_squared_error: 9.1307
#
# Epoch 00020: val_loss did not improve from 11.71272
# Epoch 21/25
# 6070763/6070763 [==============================] - 170s 28us/step - loss: 11.6161 - mean_squared_error: 8.7387 - val_loss: 11.5082 - val_mean_squared_error: 8.6076
#
# Epoch 00021: val_loss improved from 11.71272 to 11.50822, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-4-21
# Epoch 22/25
# 6070763/6070763 [==============================] - 170s 28us/step - loss: 11.5796 - mean_squared_error: 8.6950 - val_loss: 11.5344 - val_mean_squared_error: 8.6465
#
# Epoch 00022: val_loss did not improve from 11.50822
# Epoch 23/25
# 6070763/6070763 [==============================] - 170s 28us/step - loss: 11.5338 - mean_squared_error: 8.6323 - val_loss: 12.6050 - val_mean_squared_error: 9.6972
#
# Epoch 00023: val_loss did not improve from 11.50822
# Epoch 24/25
# 6070763/6070763 [==============================] - 170s 28us/step - loss: 11.4936 - mean_squared_error: 8.5851 - val_loss: 11.7239 - val_mean_squared_error: 8.8132
#
# Epoch 00024: val_loss did not improve from 11.50822
# Epoch 25/25
# 6070763/6070763 [==============================] - 170s 28us/step - loss: 11.4574 - mean_squared_error: 8.5438 - val_loss: 11.4269 - val_mean_squared_error: 8.5126
#
# Epoch 00025: val_loss improved from 11.50822 to 11.42688, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-4-25
# 5
# batch_size:  50000
# layers:  [20, 50, 20, 20]
# hidden_activations: ['relu', 'relu', 'relu', 'relu']
# l1_kernel:  [0.0, 0.0, 0.0, 0.0]
# l2_kernel:  [0.1, 0.1, 0.1, 0.1]
# Train on 6070763 samples, validate on 1517244 samples
# Epoch 1/25
# 6070763/6070763 [==============================] - 248s 41us/step - loss: 9.7960 - mean_squared_error: 5.9690 - val_loss: 8.1264 - val_mean_squared_error: 4.7427
#
# Epoch 00001: val_loss improved from inf to 8.12644, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-5-01
# Epoch 2/25
# 6070763/6070763 [==============================] - 249s 41us/step - loss: 8.5939 - mean_squared_error: 5.3458 - val_loss: 7.9016 - val_mean_squared_error: 4.5983
#
# Epoch 00002: val_loss improved from 8.12644 to 7.90163, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-5-02
# Epoch 3/25
# 6070763/6070763 [==============================] - 248s 41us/step - loss: 8.4615 - mean_squared_error: 5.3932 - val_loss: 9.0460 - val_mean_squared_error: 5.9956
#
# Epoch 00003: val_loss did not improve from 7.90163
# Epoch 4/25
# 6070763/6070763 [==============================] - 249s 41us/step - loss: 8.4315 - mean_squared_error: 5.5058 - val_loss: 7.2874 - val_mean_squared_error: 4.4848
#
# Epoch 00004: val_loss improved from 7.90163 to 7.28737, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-5-04
# Epoch 5/25
# 6070763/6070763 [==============================] - 248s 41us/step - loss: 8.3924 - mean_squared_error: 5.5632 - val_loss: 7.9297 - val_mean_squared_error: 5.1790
#
# Epoch 00005: val_loss did not improve from 7.28737
# Epoch 6/25
# 6070763/6070763 [==============================] - 249s 41us/step - loss: 8.3740 - mean_squared_error: 5.5840 - val_loss: 8.9622 - val_mean_squared_error: 6.1555
#
# Epoch 00006: val_loss did not improve from 7.28737
# Epoch 7/25
# 6070763/6070763 [==============================] - 249s 41us/step - loss: 8.3884 - mean_squared_error: 5.6840 - val_loss: 7.5602 - val_mean_squared_error: 4.9641
#
# Epoch 00007: val_loss did not improve from 7.28737
# Epoch 8/25
# 6070763/6070763 [==============================] - 248s 41us/step - loss: 8.3192 - mean_squared_error: 5.6633 - val_loss: 7.6349 - val_mean_squared_error: 5.0260
#
# Epoch 00008: val_loss did not improve from 7.28737
# Epoch 9/25
# 6070763/6070763 [==============================] - 249s 41us/step - loss: 8.2971 - mean_squared_error: 5.6638 - val_loss: 7.2482 - val_mean_squared_error: 4.6561
#
# Epoch 00009: val_loss improved from 7.28737 to 7.24817, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-5-09
# Epoch 10/25
# 6070763/6070763 [==============================] - 248s 41us/step - loss: 8.2382 - mean_squared_error: 5.6480 - val_loss: 8.5188 - val_mean_squared_error: 5.9739
#
# Epoch 00010: val_loss did not improve from 7.24817
# Epoch 11/25
# 6070763/6070763 [==============================] - 249s 41us/step - loss: 8.2233 - mean_squared_error: 5.6520 - val_loss: 7.4954 - val_mean_squared_error: 5.0113
#
# Epoch 00011: val_loss did not improve from 7.24817
# Epoch 12/25
# 6070763/6070763 [==============================] - 249s 41us/step - loss: 8.2278 - mean_squared_error: 5.6867 - val_loss: 7.2238 - val_mean_squared_error: 4.7106
#
# Epoch 00012: val_loss improved from 7.24817 to 7.22376, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-5-12
# Epoch 13/25
# 6070763/6070763 [==============================] - 248s 41us/step - loss: 8.1941 - mean_squared_error: 5.6716 - val_loss: 7.2871 - val_mean_squared_error: 4.7428
#
# Epoch 00013: val_loss did not improve from 7.22376
# Epoch 14/25
# 6070763/6070763 [==============================] - 249s 41us/step - loss: 8.2236 - mean_squared_error: 5.7105 - val_loss: 8.5052 - val_mean_squared_error: 6.0684
#
# Epoch 00014: val_loss did not improve from 7.22376
# Epoch 15/25
# 6070763/6070763 [==============================] - 249s 41us/step - loss: 8.1608 - mean_squared_error: 5.6747 - val_loss: 8.1000 - val_mean_squared_error: 5.6996
#
# Epoch 00015: val_loss did not improve from 7.22376
# Epoch 16/25
# 6070763/6070763 [==============================] - 249s 41us/step - loss: 8.4983 - mean_squared_error: 6.0755 - val_loss: 8.8999 - val_mean_squared_error: 6.6081
#
# Epoch 00016: val_loss did not improve from 7.22376
# Epoch 17/25
# 6070763/6070763 [==============================] - 249s 41us/step - loss: 8.6171 - mean_squared_error: 6.2574 - val_loss: 9.7328 - val_mean_squared_error: 7.4075
#
# Epoch 00017: val_loss did not improve from 7.22376
# Epoch 18/25
# 6070763/6070763 [==============================] - 248s 41us/step - loss: 8.6128 - mean_squared_error: 6.2580 - val_loss: 8.0875 - val_mean_squared_error: 5.7382
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 00018: val_loss did not improve from 7.22376
# Epoch 19/25
# 6070763/6070763 [==============================] - 248s 41us/step - loss: 6.4225 - mean_squared_error: 4.0812 - val_loss: 6.4128 - val_mean_squared_error: 4.1383
#
# Epoch 00019: val_loss improved from 7.22376 to 6.41280, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-5-19
# Epoch 20/25
# 6070763/6070763 [==============================] - 247s 41us/step - loss: 6.2241 - mean_squared_error: 3.9423 - val_loss: 6.0587 - val_mean_squared_error: 3.7649
#
# Epoch 00020: val_loss improved from 6.41280 to 6.05872, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-5-20
# Epoch 21/25
# 6070763/6070763 [==============================] - 246s 40us/step - loss: 6.1504 - mean_squared_error: 3.8685 - val_loss: 6.2058 - val_mean_squared_error: 3.9652
#
# Epoch 00021: val_loss did not improve from 6.05872
# Epoch 22/25
# 6070763/6070763 [==============================] - 247s 41us/step - loss: 6.1179 - mean_squared_error: 3.8588 - val_loss: 6.1581 - val_mean_squared_error: 3.9031
#
# Epoch 00022: val_loss did not improve from 6.05872
# Epoch 23/25
# 6070763/6070763 [==============================] - 246s 41us/step - loss: 6.0924 - mean_squared_error: 3.8434 - val_loss: 6.0670 - val_mean_squared_error: 3.8634
#
# Epoch 00023: val_loss did not improve from 6.05872
# Epoch 24/25
# 6070763/6070763 [==============================] - 247s 41us/step - loss: 6.0703 - mean_squared_error: 3.8366 - val_loss: 6.4648 - val_mean_squared_error: 4.2756
#
# Epoch 00024: val_loss did not improve from 6.05872
# Epoch 25/25
# 6070763/6070763 [==============================] - 247s 41us/step - loss: 6.0475 - mean_squared_error: 3.8292 - val_loss: 5.8732 - val_mean_squared_error: 3.6612
#
# Epoch 00025: val_loss improved from 6.05872 to 5.87315, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-5-25
# 6
# batch_size:  50000
# layers:  [10, 10]
# hidden_activations: ['relu', 'relu']
# l1_kernel:  [0.1, 0.1]
# l2_kernel:  [0.0, 0.0]
# Train on 6070763 samples, validate on 1517244 samples
# Epoch 1/25
# 6070763/6070763 [==============================] - 197s 32us/step - loss: 9.2237 - mean_squared_error: 5.0622 - val_loss: 7.3205 - val_mean_squared_error: 3.5872
#
# Epoch 00001: val_loss improved from inf to 7.32050, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-6-01
# Epoch 2/25
# 6070763/6070763 [==============================] - 196s 32us/step - loss: 7.3856 - mean_squared_error: 3.8661 - val_loss: 7.0593 - val_mean_squared_error: 3.6701
#
# Epoch 00002: val_loss improved from 7.32050 to 7.05935, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-6-02
# Epoch 3/25
# 6070763/6070763 [==============================] - 196s 32us/step - loss: 6.7536 - mean_squared_error: 3.4592 - val_loss: 6.4937 - val_mean_squared_error: 3.2387
#
# Epoch 00003: val_loss improved from 7.05935 to 6.49365, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-6-03
# Epoch 4/25
# 6070763/6070763 [==============================] - 197s 32us/step - loss: 6.3668 - mean_squared_error: 3.1967 - val_loss: 8.3459 - val_mean_squared_error: 5.2546
#
# Epoch 00004: val_loss did not improve from 6.49365
# Epoch 5/25
# 6070763/6070763 [==============================] - 197s 32us/step - loss: 6.2055 - mean_squared_error: 3.1492 - val_loss: 6.3092 - val_mean_squared_error: 3.2914
#
# Epoch 00005: val_loss improved from 6.49365 to 6.30918, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-6-05
# Epoch 6/25
# 6070763/6070763 [==============================] - 197s 32us/step - loss: 6.0906 - mean_squared_error: 3.1147 - val_loss: 5.5498 - val_mean_squared_error: 2.5993
#
# Epoch 00006: val_loss improved from 6.30918 to 5.54981, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-6-06
# Epoch 7/25
# 6070763/6070763 [==============================] - 197s 32us/step - loss: 6.0112 - mean_squared_error: 3.0656 - val_loss: 5.6225 - val_mean_squared_error: 2.6813
#
# Epoch 00007: val_loss did not improve from 5.54981
# Epoch 8/25
# 6070763/6070763 [==============================] - 198s 33us/step - loss: 6.0508 - mean_squared_error: 3.1893 - val_loss: 5.7590 - val_mean_squared_error: 3.0052
#
# Epoch 00008: val_loss did not improve from 5.54981
# Epoch 9/25
# 6070763/6070763 [==============================] - 197s 33us/step - loss: 6.1947 - mean_squared_error: 3.5432 - val_loss: 5.8035 - val_mean_squared_error: 3.1482
#
# Epoch 00009: val_loss did not improve from 5.54981
# Epoch 10/25
# 6070763/6070763 [==============================] - 197s 32us/step - loss: 6.1805 - mean_squared_error: 3.5853 - val_loss: 5.7633 - val_mean_squared_error: 3.1865
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 00010: val_loss did not improve from 5.54981
# Epoch 11/25
# 6070763/6070763 [==============================] - 196s 32us/step - loss: 5.2958 - mean_squared_error: 2.8110 - val_loss: 5.1787 - val_mean_squared_error: 2.7566
#
# Epoch 00011: val_loss improved from 5.54981 to 5.17865, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-6-11
# Epoch 12/25
# 6070763/6070763 [==============================] - 197s 32us/step - loss: 5.2000 - mean_squared_error: 2.8223 - val_loss: 5.1482 - val_mean_squared_error: 2.8136
#
# Epoch 00012: val_loss improved from 5.17865 to 5.14824, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-6-12
# Epoch 13/25
# 6070763/6070763 [==============================] - 197s 32us/step - loss: 5.1525 - mean_squared_error: 2.8422 - val_loss: 5.0966 - val_mean_squared_error: 2.8116
#
# Epoch 00013: val_loss improved from 5.14824 to 5.09664, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-6-13
# Epoch 14/25
# 6070763/6070763 [==============================] - 196s 32us/step - loss: 5.1246 - mean_squared_error: 2.8496 - val_loss: 5.1368 - val_mean_squared_error: 2.8807
#
# Epoch 00014: val_loss did not improve from 5.09664
# Epoch 15/25
# 6070763/6070763 [==============================] - 197s 32us/step - loss: 5.1023 - mean_squared_error: 2.8517 - val_loss: 5.0240 - val_mean_squared_error: 2.7814
#
# Epoch 00015: val_loss improved from 5.09664 to 5.02400, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-6-15
# Epoch 16/25
# 6070763/6070763 [==============================] - 197s 32us/step - loss: 5.0813 - mean_squared_error: 2.8476 - val_loss: 5.0169 - val_mean_squared_error: 2.7947
#
# Epoch 00016: val_loss improved from 5.02400 to 5.01687, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-6-16
# Epoch 17/25
# 6070763/6070763 [==============================] - 197s 32us/step - loss: 5.0653 - mean_squared_error: 2.8501 - val_loss: 5.0091 - val_mean_squared_error: 2.8001
#
# Epoch 00017: val_loss improved from 5.01687 to 5.00912, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-6-17
# Epoch 18/25
# 6070763/6070763 [==============================] - 200s 33us/step - loss: 5.0467 - mean_squared_error: 2.8438 - val_loss: 4.9763 - val_mean_squared_error: 2.7832
#
# Epoch 00018: val_loss improved from 5.00912 to 4.97630, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-6-18
# Epoch 19/25
# 6070763/6070763 [==============================] - 200s 33us/step - loss: 5.0331 - mean_squared_error: 2.8422 - val_loss: 5.0212 - val_mean_squared_error: 2.8348
#
# Epoch 00019: val_loss did not improve from 4.97630
# Epoch 20/25
# 6070763/6070763 [==============================] - 200s 33us/step - loss: 5.0164 - mean_squared_error: 2.8410 - val_loss: 4.9600 - val_mean_squared_error: 2.7865
#
# Epoch 00020: val_loss improved from 4.97630 to 4.95997, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-6-20
# Epoch 21/25
# 6070763/6070763 [==============================] - 200s 33us/step - loss: 5.0035 - mean_squared_error: 2.8406 - val_loss: 4.9775 - val_mean_squared_error: 2.8005
#
# Epoch 00021: val_loss did not improve from 4.95997
# Epoch 22/25
# 6070763/6070763 [==============================] - 201s 33us/step - loss: 4.9899 - mean_squared_error: 2.8311 - val_loss: 4.9172 - val_mean_squared_error: 2.7596
#
# Epoch 00022: val_loss improved from 4.95997 to 4.91719, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-6-22
# Epoch 23/25
# 6070763/6070763 [==============================] - 200s 33us/step - loss: 4.9777 - mean_squared_error: 2.8304 - val_loss: 5.0548 - val_mean_squared_error: 2.9093
#
# Epoch 00023: val_loss did not improve from 4.91719
# Epoch 24/25
# 6070763/6070763 [==============================] - 200s 33us/step - loss: 4.9668 - mean_squared_error: 2.8227 - val_loss: 4.8738 - val_mean_squared_error: 2.7492
#
# ...
# Epoch 7/25
# 6070763/6070763 [==============================] - 191s 31us/step - loss: 11.3889 - mean_squared_error: 9.8171 - val_loss: 11.4852 - val_mean_squared_error: 9.9324
#
# Epoch 00007: val_loss did not improve from 11.37230
# Epoch 8/25
# 6070763/6070763 [==============================] - 192s 32us/step - loss: 11.2591 - mean_squared_error: 9.6924 - val_loss: 11.0790 - val_mean_squared_error: 9.5490
#
# Epoch 00008: val_loss improved from 11.37230 to 11.07897, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-22-08
# Epoch 9/25
# 6070763/6070763 [==============================] - 191s 31us/step - loss: 11.1998 - mean_squared_error: 9.6558 - val_loss: 11.0445 - val_mean_squared_error: 9.4842
#
# Epoch 00009: val_loss improved from 11.07897 to 11.04454, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-22-09
# Epoch 10/25
# 6070763/6070763 [==============================] - 191s 31us/step - loss: 11.1068 - mean_squared_error: 9.5554 - val_loss: 10.7163 - val_mean_squared_error: 9.1900
#
# Epoch 00010: val_loss improved from 11.04454 to 10.71634, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-22-10
# Epoch 11/25
# 6070763/6070763 [==============================] - 191s 31us/step - loss: 11.0119 - mean_squared_error: 9.4745 - val_loss: 10.7431 - val_mean_squared_error: 9.2117
#
# Epoch 00011: val_loss did not improve from 10.71634
# Epoch 12/25
# 6070763/6070763 [==============================] - 191s 32us/step - loss: 10.9409 - mean_squared_error: 9.4061 - val_loss: 11.7507 - val_mean_squared_error: 10.2090
#
# Epoch 00012: val_loss did not improve from 10.71634
# Epoch 13/25
# 6070763/6070763 [==============================] - 191s 32us/step - loss: 10.8754 - mean_squared_error: 9.3430 - val_loss: 10.8917 - val_mean_squared_error: 9.3406
#
# Epoch 00013: val_loss did not improve from 10.71634
# Epoch 14/25
# 6070763/6070763 [==============================] - 191s 31us/step - loss: 10.8064 - mean_squared_error: 9.2762 - val_loss: 10.3691 - val_mean_squared_error: 8.8352
#
# Epoch 00014: val_loss improved from 10.71634 to 10.36910, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-22-14
# Epoch 15/25
# 6070763/6070763 [==============================] - 191s 31us/step - loss: 10.7568 - mean_squared_error: 9.2344 - val_loss: 10.2474 - val_mean_squared_error: 8.7181
#
# Epoch 00015: val_loss improved from 10.36910 to 10.24744, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-22-15
# Epoch 16/25
# 6070763/6070763 [==============================] - 191s 31us/step - loss: 10.7031 - mean_squared_error: 9.1822 - val_loss: 11.0985 - val_mean_squared_error: 9.5869
#
# Epoch 00016: val_loss did not improve from 10.24744
# Epoch 17/25
# 6070763/6070763 [==============================] - 191s 31us/step - loss: 10.6497 - mean_squared_error: 9.1332 - val_loss: 10.3288 - val_mean_squared_error: 8.8090
#
# Epoch 00017: val_loss did not improve from 10.24744
# Epoch 18/25
# 6070763/6070763 [==============================] - 191s 31us/step - loss: 10.6151 - mean_squared_error: 9.0969 - val_loss: 15.1628 - val_mean_squared_error: 13.6675
#
# Epoch 00018: val_loss did not improve from 10.24744
# Epoch 19/25
# 6070763/6070763 [==============================] - 190s 31us/step - loss: 10.5745 - mean_squared_error: 9.0661 - val_loss: 11.3280 - val_mean_squared_error: 9.8245
#
# Epoch 00019: val_loss did not improve from 10.24744
# Epoch 20/25
# 6070763/6070763 [==============================] - 190s 31us/step - loss: 10.5401 - mean_squared_error: 9.0331 - val_loss: 10.4126 - val_mean_squared_error: 8.9055
#
# Epoch 00020: val_loss did not improve from 10.24744
# Epoch 21/25
# 6070763/6070763 [==============================] - 191s 31us/step - loss: 10.5015 - mean_squared_error: 8.9951 - val_loss: 10.5371 - val_mean_squared_error: 9.0309
#
# Epoch 00021: val_loss did not improve from 10.24744
# Epoch 22/25
# 6070763/6070763 [==============================] - 191s 31us/step - loss: 10.4802 - mean_squared_error: 8.9758 - val_loss: 9.8306 - val_mean_squared_error: 8.3471
#
# Epoch 00022: val_loss improved from 10.24744 to 9.83060, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-22-22
# Epoch 23/25
# 6070763/6070763 [==============================] - 192s 32us/step - loss: 10.4436 - mean_squared_error: 8.9483 - val_loss: 9.9516 - val_mean_squared_error: 8.4560
#
# Epoch 00023: val_loss did not improve from 9.83060
# Epoch 24/25
# 6070763/6070763 [==============================] - 192s 32us/step - loss: 10.4208 - mean_squared_error: 8.9237 - val_loss: 9.8866 - val_mean_squared_error: 8.3889
#
# Epoch 00024: val_loss did not improve from 9.83060
# Epoch 25/25
# 6070763/6070763 [==============================] - 192s 32us/step - loss: 10.4000 - mean_squared_error: 8.9030 - val_loss: 10.7452 - val_mean_squared_error: 9.2368
#
# Epoch 00025: val_loss did not improve from 9.83060
# 23
# batch_size:  1000
# layers:  [10, 10, 10, 20]
# hidden_activations: ['relu', 'relu', 'relu', 'relu']
# l1_kernel:  [0.0, 0.0, 0.0, 0.0]
# l2_kernel:  [0.05, 0.05, 0.05, 0.05]
# Train on 6070763 samples, validate on 1517244 samples
# Epoch 1/25
# 6070763/6070763 [==============================] - 269s 44us/step - loss: 7.9412 - mean_squared_error: 4.8997 - val_loss: 8.4474 - val_mean_squared_error: 5.6267
#
# Epoch 00001: val_loss improved from inf to 8.44739, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-23-01
# Epoch 2/25
# 6070763/6070763 [==============================] - 267s 44us/step - loss: 6.9353 - mean_squared_error: 4.2697 - val_loss: 6.7424 - val_mean_squared_error: 4.1168
#
# Epoch 00002: val_loss improved from 8.44739 to 6.74239, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-23-02
# Epoch 3/25
# 6070763/6070763 [==============================] - 269s 44us/step - loss: 6.7377 - mean_squared_error: 4.2067 - val_loss: 7.0702 - val_mean_squared_error: 4.5687
#
# Epoch 00003: val_loss did not improve from 6.74239
# Epoch 4/25
# 6070763/6070763 [==============================] - 267s 44us/step - loss: 6.6150 - mean_squared_error: 4.1364 - val_loss: 5.3827 - val_mean_squared_error: 2.8946
#
# Epoch 00004: val_loss improved from 6.74239 to 5.38273, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-23-04
# Epoch 5/25
# 6070763/6070763 [==============================] - 269s 44us/step - loss: 6.6270 - mean_squared_error: 4.1518 - val_loss: 5.2814 - val_mean_squared_error: 2.7434
#
# Epoch 00005: val_loss improved from 5.38273 to 5.28141, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-23-05
# Epoch 6/25
# 6070763/6070763 [==============================] - 267s 44us/step - loss: 6.5357 - mean_squared_error: 4.0737 - val_loss: 8.8817 - val_mean_squared_error: 6.4091
#
# Epoch 00006: val_loss did not improve from 5.28141
# Epoch 7/25
# 6070763/6070763 [==============================] - 269s 44us/step - loss: 6.4980 - mean_squared_error: 4.0773 - val_loss: 6.4599 - val_mean_squared_error: 4.0242
#
# Epoch 00007: val_loss did not improve from 5.28141
# Epoch 8/25
# 6070763/6070763 [==============================] - 268s 44us/step - loss: 6.4591 - mean_squared_error: 4.0721 - val_loss: 4.9516 - val_mean_squared_error: 2.5929
#
# Epoch 00008: val_loss improved from 5.28141 to 4.95162, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-23-08
# Epoch 9/25
# 6070763/6070763 [==============================] - 269s 44us/step - loss: 6.4306 - mean_squared_error: 4.0641 - val_loss: 5.8794 - val_mean_squared_error: 3.4662
#
# Epoch 00009: val_loss did not improve from 4.95162
# Epoch 10/25
# 6070763/6070763 [==============================] - 268s 44us/step - loss: 6.4122 - mean_squared_error: 4.0537 - val_loss: 5.0351 - val_mean_squared_error: 2.6646
#
# Epoch 00010: val_loss did not improve from 4.95162
# Epoch 11/25
# 6070763/6070763 [==============================] - 268s 44us/step - loss: 6.4152 - mean_squared_error: 4.0936 - val_loss: 6.6121 - val_mean_squared_error: 4.2868
#
# Epoch 00011: val_loss did not improve from 4.95162
# Epoch 12/25
# 6070763/6070763 [==============================] - 268s 44us/step - loss: 6.4625 - mean_squared_error: 4.1358 - val_loss: 5.1544 - val_mean_squared_error: 2.7968
#
# Epoch 00012: val_loss did not improve from 4.95162
# Epoch 13/25
# 6070763/6070763 [==============================] - 267s 44us/step - loss: 6.3870 - mean_squared_error: 4.0852 - val_loss: 4.9561 - val_mean_squared_error: 2.6592
#
# Epoch 00013: val_loss did not improve from 4.95162
# Epoch 14/25
# 6070763/6070763 [==============================] - 268s 44us/step - loss: 6.3919 - mean_squared_error: 4.0961 - val_loss: 8.0292 - val_mean_squared_error: 5.7453
#
# Epoch 00014: val_loss did not improve from 4.95162
# Epoch 15/25
# 6070763/6070763 [==============================] - 267s 44us/step - loss: 6.4435 - mean_squared_error: 4.1523 - val_loss: 6.1661 - val_mean_squared_error: 3.9651
#
# Epoch 00015: val_loss did not improve from 4.95162
# Epoch 16/25
# 6070763/6070763 [==============================] - 268s 44us/step - loss: 6.4304 - mean_squared_error: 4.1345 - val_loss: 5.2325 - val_mean_squared_error: 3.0199
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 00016: val_loss did not improve from 4.95162
# Epoch 17/25
# 6070763/6070763 [==============================] - 267s 44us/step - loss: 3.9971 - mean_squared_error: 1.8690 - val_loss: 3.7754 - val_mean_squared_error: 1.7206
#
# Epoch 00017: val_loss improved from 4.95162 to 3.77540, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-23-17
# Epoch 18/25
# 6070763/6070763 [==============================] - 269s 44us/step - loss: 3.7634 - mean_squared_error: 1.7502 - val_loss: 3.5219 - val_mean_squared_error: 1.5344
#
# Epoch 00018: val_loss improved from 3.77540 to 3.52187, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-23-18
# Epoch 19/25
# 6070763/6070763 [==============================] - 268s 44us/step - loss: 3.6738 - mean_squared_error: 1.7188 - val_loss: 3.5457 - val_mean_squared_error: 1.5917
#
# Epoch 00019: val_loss did not improve from 3.52187
# Epoch 20/25
# 6070763/6070763 [==============================] - 270s 44us/step - loss: 3.6263 - mean_squared_error: 1.7150 - val_loss: 3.3923 - val_mean_squared_error: 1.5018
#
# Epoch 00020: val_loss improved from 3.52187 to 3.39230, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-23-20
# Epoch 21/25
# 6070763/6070763 [==============================] - 268s 44us/step - loss: 3.5980 - mean_squared_error: 1.7219 - val_loss: 3.6754 - val_mean_squared_error: 1.8256
#
# Epoch 00021: val_loss did not improve from 3.39230
# Epoch 22/25
# 6070763/6070763 [==============================] - 269s 44us/step - loss: 3.5636 - mean_squared_error: 1.7185 - val_loss: 3.4314 - val_mean_squared_error: 1.6192
#
# Epoch 00022: val_loss did not improve from 3.39230
# Epoch 23/25
# 6070763/6070763 [==============================] - 271s 45us/step - loss: 3.5380 - mean_squared_error: 1.7277 - val_loss: 3.3790 - val_mean_squared_error: 1.5791
#
# Epoch 00023: val_loss improved from 3.39230 to 3.37895, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-23-23
# Epoch 24/25
# 6070763/6070763 [==============================] - 272s 45us/step - loss: 3.5122 - mean_squared_error: 1.7206 - val_loss: 3.3311 - val_mean_squared_error: 1.5213
#
# Epoch 00024: val_loss improved from 3.37895 to 3.33112, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-23-24
# Epoch 25/25
# 6070763/6070763 [==============================] - 272s 45us/step - loss: 3.4938 - mean_squared_error: 1.7127 - val_loss: 3.4621 - val_mean_squared_error: 1.6731
#
# Epoch 00025: val_loss did not improve from 3.33112
# 24
# batch_size:  50000
# layers:  [10]
# hidden_activations: ['relu']
# l1_kernel:  [0.2]
# l2_kernel:  [0.0]
# Train on 6070763 samples, validate on 1517244 samples
# Epoch 1/25
# 6070763/6070763 [==============================] - 199s 33us/step - loss: 19.6077 - mean_squared_error: 18.0509 - val_loss: 18.7756 - val_mean_squared_error: 17.5152
#
# Epoch 00001: val_loss improved from inf to 18.77563, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-24-01
# Epoch 2/25
# 6070763/6070763 [==============================] - 198s 33us/step - loss: 18.6449 - mean_squared_error: 17.4998 - val_loss: 18.6535 - val_mean_squared_error: 17.5907
#
# Epoch 00002: val_loss improved from 18.77563 to 18.65347, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-24-02
# Epoch 3/25
# 6070763/6070763 [==============================] - 197s 32us/step - loss: 18.4745 - mean_squared_error: 17.4889 - val_loss: 18.4197 - val_mean_squared_error: 17.4822
#
# Epoch 00003: val_loss improved from 18.65347 to 18.41966, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-24-03
# Epoch 4/25
# 6070763/6070763 [==============================] - 197s 33us/step - loss: 18.3950 - mean_squared_error: 17.4899 - val_loss: 18.7702 - val_mean_squared_error: 17.8635
#
# Epoch 00004: val_loss did not improve from 18.41966
# Epoch 5/25
# 6070763/6070763 [==============================] - 197s 32us/step - loss: 18.3482 - mean_squared_error: 17.4882 - val_loss: 18.1662 - val_mean_squared_error: 17.3221
#
# Epoch 00005: val_loss improved from 18.41966 to 18.16624, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-24-05
# Epoch 6/25
# 6070763/6070763 [==============================] - 197s 32us/step - loss: 18.3299 - mean_squared_error: 17.5021 - val_loss: 18.8728 - val_mean_squared_error: 18.0427
#
# Epoch 00006: val_loss did not improve from 18.16624
# Epoch 7/25
# 6070763/6070763 [==============================] - 197s 32us/step - loss: 18.3092 - mean_squared_error: 17.5042 - val_loss: 18.5453 - val_mean_squared_error: 17.7338
#
# Epoch 00007: val_loss did not improve from 18.16624
# Epoch 8/25
# 6070763/6070763 [==============================] - 197s 32us/step - loss: 18.2964 - mean_squared_error: 17.5094 - val_loss: 18.5092 - val_mean_squared_error: 17.7136
#
# Epoch 00008: val_loss did not improve from 18.16624
# Epoch 9/25
# 6070763/6070763 [==============================] - 197s 32us/step - loss: 18.2963 - mean_squared_error: 17.5193 - val_loss: 18.8560 - val_mean_squared_error: 18.0508
#
# Epoch 00009: val_loss did not improve from 18.16624
# Epoch 10/25
# 6070763/6070763 [==============================] - 198s 33us/step - loss: 18.2941 - mean_squared_error: 17.5227 - val_loss: 18.0939 - val_mean_squared_error: 17.3473
#
# Epoch 00010: val_loss improved from 18.16624 to 18.09393, saving model to /home/afengler/git_repos/nn_likelihoods/keras_models//dnnregressor_wftp_hyp_opt_choice_rt_09_16_18_21_23_13/ckpt-24-10
# Epoch 11/25
# 6070763/6070763 [==============================] - 197s 32us/step - loss: 18.2828 - mean_squared_error: 17.5244 - val_loss: 18.4635 - val_mean_squared_error: 17.6960
#
# Epoch 00011: val_loss did not improve from 18.09393
# Epoch 00011: early stopping
# 25

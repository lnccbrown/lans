# %%
# Load packages
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import os
import pickle
import time
import scipy as scp
import scipy.stats as scps
from scipy.optimize import differential_evolution
from scipy.optimize import minimize
from datetime import datetime
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Load my own functions
import dnnregressor_train_eval_keras as dnnk
import make_data_wfpt as mdw
from kde_training_utilities import kde_load_data
import ddm_data_simulation as ddm_sim
import boundary_functions as bf

# %%
# Handle some cuda business

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="2"

from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 3778554823880319033
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 1793211789012344132
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 12048649421
# locality {
#   bus_id: 2
#   numa_node: 1
#   links {
#   }
# }
# incarnation: 14128844306589753901
# physical_device_desc: "device: 0, name: GeForce GTX TITAN X, pci bus id: 0000:82:00.0, compute capability: 5.2"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 1002963290607403044
# physical_device_desc: "device: XLA_GPU device"
# ]

# %%
# Load Model
model_path = '/media/data_cifs/afengler/data/kde/ornstein_uhlenbeck/keras_models/dnnregressor_ornstein_uhlenbeck_06_28_19_00_43_25/model_0' 
ckpt_path = '/media/data_cifs/afengler/data/kde/ornstein_uhlenbeck/keras_models/dnnregressor_ornstein_uhlenbeck_06_28_19_00_43_25/ckpt_0_60'

model = keras.models.load_model(model_path)
model.load_weights(ckpt_path)

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 6)                 0
# _________________________________________________________________
# dense (Dense)                (None, 20)                140
# _________________________________________________________________
# dense_1 (Dense)              (None, 40)                840
# _________________________________________________________________
# dense_2 (Dense)              (None, 60)                2460
# _________________________________________________________________
# dense_3 (Dense)              (None, 80)                4880
# _________________________________________________________________
# dense_4 (Dense)              (None, 100)               8100
# _________________________________________________________________
# dense_5 (Dense)              (None, 120)               12120
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 121
# =================================================================
# Total params: 28,661
# Trainable params: 28,661
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Initializations -----
n_runs = 100
n_samples = 2500
feature_file_path = '/media/data_cifs/afengler/data/kde/ornstein_uhlenbeck/train_test_data/test_features.pickle'
mle_out_path = '/media/data_cifs/afengler/data/kde/ornstein_uhlenbeck/mle_runs'

# NOTE PARAMETERS: WEIBULL: [v, a, w, node, shape, scale]
param_bounds = [(-2, 2), (0.5, 2), (0.3, 0.7), (-1.0, 1.0)]


# my_optim_columns = ['v_sim', 'a_sim', 'w_sim', 'node_sim', 'theta_sim',
#                     'v_mle', 'a_mle', 'w_mle', 'node_mle', 'theta_mle', 'n_samples']

# Get parameter names in correct ordering:
dat = pickle.load(open(feature_file_path, 
                       'rb'))

parameter_names = list(dat.keys())[:-2] # :-1 to get rid of 'rt' and 'choice' here

# Make columns for optimizer result table
p_sim = []
p_mle = []

for parameter_name in parameter_names:
    p_sim.append(parameter_name + '_sim')
    p_mle.append(parameter_name + '_mle')
    
my_optim_columns = p_sim + p_mle + ['n_samples']

# Initialize the data frame in which to store optimizer results
optim_results = pd.DataFrame(np.zeros((n_runs, len(my_optim_columns))), columns = my_optim_columns)
optim_results.iloc[:, 2 * len(parameter_names)] = n_samples

# define boundary
boundary = bf.constant
boundary_multiplicative = True

# Define the likelihood function
def log_p(params = [0, 1, 0.9], model = [], data = [], parameter_names = []):
    # Make feature array
    feature_array = np.zeros((data[0].shape[0], len(parameter_names) + 2))
    
    # Store parameters
    cnt = 0
    for i in range(0, len(parameter_names), 1):
        feature_array[:, i] = params[i]
        cnt += 1
    
    # Store rts and choices
    feature_array[:, cnt] = data[0].ravel() # rts
    feature_array[:, cnt + 1] = data[1].ravel() # choices
    
    # Get model predictions
    prediction = model.predict(feature_array)
    
    # Some post-processing of predictions
    prediction[prediction < 1e-29] = 1e-29
    
    return(- np.sum(np.log(prediction)))  

def make_params(param_bounds = []):
    params = np.zeros(len(param_bounds))
    
    for i in range(len(params)):
        params[i] = np.random.uniform(low = param_bounds[i][0], high = param_bounds[i][1])
        
    return params
# ---------------------

# %%
# Main loop ----------- TD: Parallelize
for i in range(0, n_runs, 1): 
    
    # Get start time
    start_time = time.time()
    
    tmp_params = make_params(param_bounds = param_bounds)
    
    # Store in output file
    optim_results.iloc[i, :len(parameter_names)] = tmp_params
    
    # Print some info on run
    print('Parameters for run ' + str(i) + ': ')
    print(tmp_params)
    
    # Define boundary params
    # Linear Collapse
#     boundary_params = {'node': tmp_params[3],
#                        'theta': tmp_params[4]}
    
    # Constant
    boundary_params = {}
    
    # Run model simulations
    ddm_dat_tmp = ddm_sim.ddm_flexbound_simulate(v = tmp_params[0],
                                                 a = tmp_params[1],
                                                 w = tmp_params[2],
                                                 s = 1,
                                                 delta_t = 0.001,
                                                 max_t = 20,
                                                 n_samples = n_samples,
                                                 boundary_fun = boundary, # function of t (and potentially other parameters) that takes in (t, *args)
                                                 boundary_multiplicative = boundary_multiplicative, # CAREFUL: CHECK IF BOUND
                                                 boundary_params = boundary_params)
        
    # Print some info on run
    print('Mean rt for current run: ')
    print(np.mean(ddm_dat_tmp[0]))
    
    # Run optimizer
    out = differential_evolution(log_p, 
                                 bounds = param_bounds, 
                                 args = (model, ddm_dat_tmp, parameter_names), 
                                 popsize = 30,
                                 disp = True)
    
    # Print some info
    print('Solution vector of current run: ')
    print(out.x)
    
    print('The run took: ')
    elapsed_time = time.time() - start_time
    print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
    
    # Store result in output file
    optim_results.iloc[i, len(parameter_names):(2*len(parameter_names))] = out.x
# -----------------------

# Save optimization results to file
optim_results.to_csv(mle_out_path + '/mle_results_2.csv')
# Out:
# Parameters for run 0:
# [1.21235968 1.66283634 0.58640283 0.79089091]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 1.1593447999999638
# differential_evolution step 1: f(x)= 2626.11
# differential_evolution step 2: f(x)= 2620.24
# differential_evolution step 3: f(x)= 2573.28
# differential_evolution step 4: f(x)= 2538.03
# differential_evolution step 5: f(x)= 2510.46
# differential_evolution step 6: f(x)= 2500.56
# differential_evolution step 7: f(x)= 2500.56
# differential_evolution step 8: f(x)= 2500.56
# differential_evolution step 9: f(x)= 2500.56
# differential_evolution step 10: f(x)= 2500.56
# differential_evolution step 11: f(x)= 2485.66
# differential_evolution step 12: f(x)= 2485.66
# differential_evolution step 13: f(x)= 2485.66
# differential_evolution step 14: f(x)= 2485.66
# differential_evolution step 15: f(x)= 2475.94
# differential_evolution step 16: f(x)= 2475.94
# differential_evolution step 17: f(x)= 2449.76
# differential_evolution step 18: f(x)= 2449.76
# differential_evolution step 19: f(x)= 2449.76
# differential_evolution step 20: f(x)= 2449.76
# differential_evolution step 21: f(x)= 2449.76
# differential_evolution step 22: f(x)= 2449.76
# differential_evolution step 23: f(x)= 2449.76
# differential_evolution step 24: f(x)= 2449.76
# differential_evolution step 25: f(x)= 2449.76
# differential_evolution step 26: f(x)= 2449.76
# Solution vector of current run:
# [1.26128719 1.04246542 0.39985861 0.4362377 ]
# The run took:
# 00:05:07
# Parameters for run 1:
# [-1.04554369  0.98161593  0.61860185  0.7288057 ]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.8164435999999834
# differential_evolution step 1: f(x)= 2742.34
# differential_evolution step 2: f(x)= 2600.73
# differential_evolution step 3: f(x)= 2600.73
# differential_evolution step 4: f(x)= 2600.73
# differential_evolution step 5: f(x)= 2499.03
# differential_evolution step 6: f(x)= 2499.03
# differential_evolution step 7: f(x)= 2499.03
# differential_evolution step 8: f(x)= 2453.74
# differential_evolution step 9: f(x)= 2453.74
# differential_evolution step 10: f(x)= 2452.32
# differential_evolution step 11: f(x)= 2452.32
# differential_evolution step 12: f(x)= 2452.32
# differential_evolution step 13: f(x)= 2452.32
# differential_evolution step 14: f(x)= 2452.32
# differential_evolution step 15: f(x)= 2452.32
# differential_evolution step 16: f(x)= 2443.05
# differential_evolution step 17: f(x)= 2443.05
# differential_evolution step 18: f(x)= 2443.05
# differential_evolution step 19: f(x)= 2443.05
# differential_evolution step 20: f(x)= 2443.05
# Solution vector of current run:
# [-1.86741929  0.9886257   0.66717956  0.71662978]
# The run took:
# 00:03:45
# Parameters for run 2:
# [ 0.72961388  1.64240664  0.56743051 -0.8247641 ]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 1.760208799999948
# differential_evolution step 1: f(x)= 4008.68
# differential_evolution step 2: f(x)= 3966.89
# differential_evolution step 3: f(x)= 3966.89
# differential_evolution step 4: f(x)= 3966.89
# differential_evolution step 5: f(x)= 3965.45
# differential_evolution step 6: f(x)= 3965.45
# differential_evolution step 7: f(x)= 3963.16
# differential_evolution step 8: f(x)= 3963.16
# differential_evolution step 9: f(x)= 3963.16
# differential_evolution step 10: f(x)= 3953.7
# differential_evolution step 11: f(x)= 3953.7
# differential_evolution step 12: f(x)= 3953.7
# differential_evolution step 13: f(x)= 3953.7
# Solution vector of current run:
# [0.85115751 1.32369162 0.50344163 0.165876  ]
# The run took:
# 00:03:45
# Parameters for run 3:
# [ 1.95091236  1.7554387   0.3778353  -0.97516633]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 1.1249843999999718
# differential_evolution step 1: f(x)= 1587.18
# differential_evolution step 2: f(x)= 1587.18
# differential_evolution step 3: f(x)= 1557.68
# differential_evolution step 4: f(x)= 1557.68
# differential_evolution step 5: f(x)= 1557.68
# differential_evolution step 6: f(x)= 1557.68
# differential_evolution step 7: f(x)= 1494.15
# differential_evolution step 8: f(x)= 1494.15
# differential_evolution step 9: f(x)= 1494.15
# differential_evolution step 10: f(x)= 1494.15
# differential_evolution step 11: f(x)= 1494.15
# differential_evolution step 12: f(x)= 1494.15
# differential_evolution step 13: f(x)= 1494.15
# differential_evolution step 14: f(x)= 1490.5
# differential_evolution step 15: f(x)= 1490.49
# differential_evolution step 16: f(x)= 1490.49
# differential_evolution step 17: f(x)= 1489.71
# differential_evolution step 18: f(x)= 1487.68
# differential_evolution step 19: f(x)= 1486.05
# differential_evolution step 20: f(x)= 1486.05
# differential_evolution step 21: f(x)= 1483.06
# differential_evolution step 22: f(x)= 1483.06
# differential_evolution step 23: f(x)= 1483.06
# differential_evolution step 24: f(x)= 1482.81
# Solution vector of current run:
# [ 1.75733316  1.70638577  0.39279248 -0.76471371]
# The run took:
# 00:04:34
# Parameters for run 4:
# [ 0.0265791   1.15494739  0.56103388 -0.89989094]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 1.3655359999999568
# differential_evolution step 1: f(x)= 4620.51
# differential_evolution step 2: f(x)= 4576.78
# differential_evolution step 3: f(x)= 4576.78
# differential_evolution step 4: f(x)= 4558.61
# differential_evolution step 5: f(x)= 4558.61
# differential_evolution step 6: f(x)= 4558.61
# differential_evolution step 7: f(x)= 4558.61
# differential_evolution step 8: f(x)= 4558.61
# differential_evolution step 9: f(x)= 4558.61
# Solution vector of current run:
# [0.06902052 1.07965741 0.56884389 0.04908775]
# The run took:
# 00:02:41
# Parameters for run 5:
# [0.56752933 1.11570859 0.32875892 0.97233661]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 1.1488495999999613
# differential_evolution step 1: f(x)= 4042.9
# differential_evolution step 2: f(x)= 4032.32
# differential_evolution step 3: f(x)= 3871.81
# differential_evolution step 4: f(x)= 3867.09
# differential_evolution step 5: f(x)= 3867.09
# differential_evolution step 6: f(x)= 3855.14
# differential_evolution step 7: f(x)= 3855.14
# differential_evolution step 8: f(x)= 3855.14
# differential_evolution step 9: f(x)= 3840.14
# differential_evolution step 10: f(x)= 3840.14
# differential_evolution step 11: f(x)= 3840.14
# differential_evolution step 12: f(x)= 3833.54
# differential_evolution step 13: f(x)= 3833.54
# differential_evolution step 14: f(x)= 3833.54
# Solution vector of current run:
# [0.70235112 1.02095776 0.30050808 0.01044088]
# The run took:
# 00:03:22
# Parameters for run 6:
# [0.91907906 1.47168581 0.67494627 0.53349286]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.9843399999999732
# differential_evolution step 1: f(x)= 2374.71
# differential_evolution step 2: f(x)= 2374.71
# differential_evolution step 3: f(x)= 2374.71
# differential_evolution step 4: f(x)= 2371.41
# differential_evolution step 5: f(x)= 2371.41
# differential_evolution step 6: f(x)= 2371.41
# differential_evolution step 7: f(x)= 2371.41
# differential_evolution step 8: f(x)= 2343.96
# differential_evolution step 9: f(x)= 2343.96
# differential_evolution step 10: f(x)= 2330.57
# differential_evolution step 11: f(x)= 2330.57
# differential_evolution step 12: f(x)= 2330.57
# differential_evolution step 13: f(x)= 2330.57
# differential_evolution step 14: f(x)= 2330.57
# differential_evolution step 15: f(x)= 2330.57
# differential_evolution step 16: f(x)= 2330.57
# differential_evolution step 17: f(x)= 2330.57
# differential_evolution step 18: f(x)= 2330.57
# differential_evolution step 19: f(x)= 2330.57
# differential_evolution step 20: f(x)= 2330.57
# differential_evolution step 21: f(x)= 2330.57
# differential_evolution step 22: f(x)= 2330.57
# differential_evolution step 23: f(x)= 2330.22
# differential_evolution step 24: f(x)= 2329.99
# differential_evolution step 25: f(x)= 2329.99
# Solution vector of current run:
# [1.05211665 1.08604622 0.57648704 0.30461732]
# The run took:
# 00:04:40
# Parameters for run 7:
# [0.44271097 1.73133195 0.34521601 0.97314622]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 2.768991999999936
# differential_evolution step 1: f(x)= 6092.22
# differential_evolution step 2: f(x)= 5946.76
# differential_evolution step 3: f(x)= 5946.76
# differential_evolution step 4: f(x)= 5946.76
# differential_evolution step 5: f(x)= 5935.65
# differential_evolution step 6: f(x)= 5935.65
# differential_evolution step 7: f(x)= 5885.35
# differential_evolution step 8: f(x)= 5885.35
# differential_evolution step 9: f(x)= 5850.86
# differential_evolution step 10: f(x)= 5850.86
# differential_evolution step 11: f(x)= 5850.86
# differential_evolution step 12: f(x)= 5843.13
# differential_evolution step 13: f(x)= 5843.13
# differential_evolution step 14: f(x)= 5843.13
# differential_evolution step 15: f(x)= 5833
# differential_evolution step 16: f(x)= 5833
# differential_evolution step 17: f(x)= 5833
# Solution vector of current run:
# [ 0.6477344   1.85812933  0.32099538 -0.48664377]
# The run took:
# 00:05:10
# Parameters for run 8:
# [-0.81142375  1.79418672  0.69635696  0.363131  ]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 2.3534211999999135
# differential_evolution step 1: f(x)= 5066.49
# differential_evolution step 2: f(x)= 5066.49
# differential_evolution step 3: f(x)= 4947.8
# differential_evolution step 4: f(x)= 4947.8
# differential_evolution step 5: f(x)= 4863.84
# differential_evolution step 6: f(x)= 4863.84
# differential_evolution step 7: f(x)= 4863.84
# differential_evolution step 8: f(x)= 4831.26
# differential_evolution step 9: f(x)= 4831.26
# differential_evolution step 10: f(x)= 4827.54
# differential_evolution step 11: f(x)= 4827.54
# differential_evolution step 12: f(x)= 4827.54
# differential_evolution step 13: f(x)= 4827.54
# differential_evolution step 14: f(x)= 4827.54
# differential_evolution step 15: f(x)= 4827.54
# differential_evolution step 16: f(x)= 4827.54
# differential_evolution step 17: f(x)= 4824.02
# differential_evolution step 18: f(x)= 4821.52
# Solution vector of current run:
# [-0.96327604  1.7344948   0.699893   -0.07351782]
# The run took:
# 00:05:00
# Parameters for run 9:
# [-1.39979077  0.62166894  0.66009373 -0.64095112]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.3527695999999995
# differential_evolution step 1: f(x)= 876.753
# differential_evolution step 2: f(x)= 711.757
# differential_evolution step 3: f(x)= 711.757
# differential_evolution step 4: f(x)= 711.757
# differential_evolution step 5: f(x)= 711.757
# differential_evolution step 6: f(x)= 707.818
# differential_evolution step 7: f(x)= 707.818
# differential_evolution step 8: f(x)= 692.559
# differential_evolution step 9: f(x)= 682.136
# differential_evolution step 10: f(x)= 672.169
# differential_evolution step 11: f(x)= 672.169
# differential_evolution step 12: f(x)= 670.455
# differential_evolution step 13: f(x)= 670.241
# differential_evolution step 14: f(x)= 670.241
# differential_evolution step 15: f(x)= 663.226
# differential_evolution step 16: f(x)= 663.226
# differential_evolution step 17: f(x)= 663.226
# differential_evolution step 18: f(x)= 663.226
# differential_evolution step 19: f(x)= 663.226
# differential_evolution step 20: f(x)= 663.226
# differential_evolution step 21: f(x)= 661.013
# differential_evolution step 22: f(x)= 661.013
# differential_evolution step 23: f(x)= 661.013
# differential_evolution step 24: f(x)= 660.307
# differential_evolution step 25: f(x)= 660.307
# differential_evolution step 26: f(x)= 660.307
# differential_evolution step 27: f(x)= 660.307
# differential_evolution step 28: f(x)= 660.307
# differential_evolution step 29: f(x)= 659.884
# differential_evolution step 30: f(x)= 659.884
# differential_evolution step 31: f(x)= 659.628
# differential_evolution step 32: f(x)= 659.588
# Solution vector of current run:
# [-1.58646342  0.55287341  0.69998026  0.02676844]
# The run took:
# 00:04:58
# Parameters for run 10:
# [-1.41958757  0.63725625  0.69111256 -0.02208172]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.3652739999999992
# differential_evolution step 1: f(x)= 1162.36
# differential_evolution step 2: f(x)= 921.917
# differential_evolution step 3: f(x)= 921.917
# differential_evolution step 4: f(x)= 921.917
# differential_evolution step 5: f(x)= 907.129
# differential_evolution step 6: f(x)= 907.129
# differential_evolution step 7: f(x)= 897.343
# differential_evolution step 8: f(x)= 897.343
# differential_evolution step 9: f(x)= 897.195
# differential_evolution step 10: f(x)= 886.343
# differential_evolution step 11: f(x)= 878.574
# differential_evolution step 12: f(x)= 878.574
# differential_evolution step 13: f(x)= 878.574
# differential_evolution step 14: f(x)= 878.292
# differential_evolution step 15: f(x)= 876.145
# differential_evolution step 16: f(x)= 876.145
# differential_evolution step 17: f(x)= 874.095
# differential_evolution step 18: f(x)= 872.635
# differential_evolution step 19: f(x)= 872.635
# differential_evolution step 20: f(x)= 872.635
# differential_evolution step 21: f(x)= 872.635
# differential_evolution step 22: f(x)= 871.176
# differential_evolution step 23: f(x)= 871.176
# differential_evolution step 24: f(x)= 871.176
# differential_evolution step 25: f(x)= 870.794
# Solution vector of current run:
# [-1.41533632  0.57513933  0.69910801  0.16630714]
# The run took:
# 00:04:02
# Parameters for run 11:
# [1.42591051 0.50458805 0.35963055 0.46359461]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.24627039999999997
# differential_evolution step 1: f(x)= -146.061
# differential_evolution step 2: f(x)= -146.061
# differential_evolution step 3: f(x)= -368.848
# differential_evolution step 4: f(x)= -368.848
# differential_evolution step 5: f(x)= -438.039
# differential_evolution step 6: f(x)= -438.039
# differential_evolution step 7: f(x)= -481.958
# differential_evolution step 8: f(x)= -481.958
# differential_evolution step 9: f(x)= -482.477
# differential_evolution step 10: f(x)= -482.477
# differential_evolution step 11: f(x)= -482.477
# differential_evolution step 12: f(x)= -498.445
# differential_evolution step 13: f(x)= -498.906
# differential_evolution step 14: f(x)= -501.286
# differential_evolution step 15: f(x)= -517.05
# differential_evolution step 16: f(x)= -522.063
# differential_evolution step 17: f(x)= -523.569
# differential_evolution step 18: f(x)= -523.569
# differential_evolution step 19: f(x)= -523.569
# differential_evolution step 20: f(x)= -523.569
# differential_evolution step 21: f(x)= -523.569
# differential_evolution step 22: f(x)= -523.866
# differential_evolution step 23: f(x)= -524.813
# differential_evolution step 24: f(x)= -525.399
# differential_evolution step 25: f(x)= -525.979
# differential_evolution step 26: f(x)= -526.224
# differential_evolution step 27: f(x)= -526.425
# differential_evolution step 28: f(x)= -526.425
# differential_evolution step 29: f(x)= -526.425
# differential_evolution step 30: f(x)= -526.425
# differential_evolution step 31: f(x)= -526.425
# differential_evolution step 32: f(x)= -526.425
# differential_evolution step 33: f(x)= -526.425
# differential_evolution step 34: f(x)= -526.425
# differential_evolution step 35: f(x)= -526.809
# differential_evolution step 36: f(x)= -527.067
# differential_evolution step 37: f(x)= -527.067
# Solution vector of current run:
# [ 1.89928276  0.57645173  0.42232228 -0.99840204]
# The run took:
# 00:05:50
# Parameters for run 12:
# [-1.39439214  1.32471061  0.46023651  0.6957413 ]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.8500039999999819
# differential_evolution step 1: f(x)= 1767.69
# differential_evolution step 2: f(x)= 1767.69
# differential_evolution step 3: f(x)= 1767.69
# differential_evolution step 4: f(x)= 1726.51
# differential_evolution step 5: f(x)= 1726.51
# differential_evolution step 6: f(x)= 1710.98
# differential_evolution step 7: f(x)= 1710.98
# differential_evolution step 8: f(x)= 1701.2
# differential_evolution step 9: f(x)= 1675.57
# differential_evolution step 10: f(x)= 1675.57
# differential_evolution step 11: f(x)= 1675.57
# differential_evolution step 12: f(x)= 1673.18
# differential_evolution step 13: f(x)= 1673.18
# differential_evolution step 14: f(x)= 1673.18
# differential_evolution step 15: f(x)= 1668.82
# differential_evolution step 16: f(x)= 1668.82
# differential_evolution step 17: f(x)= 1665.07
# differential_evolution step 18: f(x)= 1665.07
# differential_evolution step 19: f(x)= 1663.69
# differential_evolution step 20: f(x)= 1663.69
# differential_evolution step 21: f(x)= 1663.26
# differential_evolution step 22: f(x)= 1661.88
# differential_evolution step 23: f(x)= 1661.88
# differential_evolution step 24: f(x)= 1660.08
# differential_evolution step 25: f(x)= 1660.08
# differential_evolution step 26: f(x)= 1660.08
# Solution vector of current run:
# [-1.85451226  1.01039163  0.58081184  0.98471974]
# The run took:
# 00:04:44
# Parameters for run 13:
# [ 1.24740298  1.62074312  0.67821807 -0.1753391 ]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.8491971999999798
# differential_evolution step 1: f(x)= 1895.66
# differential_evolution step 2: f(x)= 1895.66
# differential_evolution step 3: f(x)= 1868.1
# differential_evolution step 4: f(x)= 1868.1
# differential_evolution step 5: f(x)= 1820.68
# differential_evolution step 6: f(x)= 1820.04
# differential_evolution step 7: f(x)= 1791.81
# differential_evolution step 8: f(x)= 1791.81
# differential_evolution step 9: f(x)= 1779
# differential_evolution step 10: f(x)= 1779
# differential_evolution step 11: f(x)= 1777.45
# differential_evolution step 12: f(x)= 1772.62
# differential_evolution step 13: f(x)= 1762.65
# differential_evolution step 14: f(x)= 1762.65
# differential_evolution step 15: f(x)= 1762.65
# differential_evolution step 16: f(x)= 1762.65
# differential_evolution step 17: f(x)= 1762.65
# differential_evolution step 18: f(x)= 1762.65
# differential_evolution step 19: f(x)= 1762.65
# differential_evolution step 20: f(x)= 1762.65
# differential_evolution step 21: f(x)= 1762.65
# differential_evolution step 22: f(x)= 1762.65
# differential_evolution step 23: f(x)= 1762.65
# differential_evolution step 24: f(x)= 1762.65
# differential_evolution step 25: f(x)= 1762.65
# differential_evolution step 26: f(x)= 1762.65
# differential_evolution step 27: f(x)= 1762.65
# differential_evolution step 28: f(x)= 1761.35
# differential_evolution step 29: f(x)= 1761.35
# differential_evolution step 30: f(x)= 1761.35
# differential_evolution step 31: f(x)= 1759.8
# differential_evolution step 32: f(x)= 1759.8
# differential_evolution step 33: f(x)= 1759.8
# Solution vector of current run:
# [ 1.05911569  1.27126214  0.62166167 -0.26446584]
# The run took:
# 00:05:31
# Parameters for run 14:
# [-0.15519921  1.77285504  0.36589768 -0.13226072]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 2.7597959999999517
# differential_evolution step 1: f(x)= 5993.43
# differential_evolution step 2: f(x)= 5993.43
# differential_evolution step 3: f(x)= 5895.98
# differential_evolution step 4: f(x)= 5895.98
# differential_evolution step 5: f(x)= 5895.98
# differential_evolution step 6: f(x)= 5879.98
# differential_evolution step 7: f(x)= 5879.98
# differential_evolution step 8: f(x)= 5879.98
# differential_evolution step 9: f(x)= 5879.98
# differential_evolution step 10: f(x)= 5879.98
# differential_evolution step 11: f(x)= 5879.98
# differential_evolution step 12: f(x)= 5878.42
# Solution vector of current run:
# [ 0.01840398  1.90323315  0.37541374 -0.75023687]
# The run took:
# 00:04:31
# Parameters for run 15:
# [1.4053593  1.85823829 0.55198642 0.54575204]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 1.1969863999999635
# differential_evolution step 1: f(x)= 2410.7
# differential_evolution step 2: f(x)= 2410.7
# differential_evolution step 3: f(x)= 2326.41
# differential_evolution step 4: f(x)= 2326.41
# differential_evolution step 5: f(x)= 2263.69
# differential_evolution step 6: f(x)= 2206.02
# differential_evolution step 7: f(x)= 2206.02
# differential_evolution step 8: f(x)= 2184.86
# differential_evolution step 9: f(x)= 2184.86
# differential_evolution step 10: f(x)= 2184.86
# differential_evolution step 11: f(x)= 2184.86
# differential_evolution step 12: f(x)= 2184.86
# differential_evolution step 13: f(x)= 2184.86
# differential_evolution step 14: f(x)= 2184.86
# differential_evolution step 15: f(x)= 2177.19
# differential_evolution step 16: f(x)= 2164.53
# differential_evolution step 17: f(x)= 2159.25
# differential_evolution step 18: f(x)= 2159.25
# differential_evolution step 19: f(x)= 2159.25
# differential_evolution step 20: f(x)= 2159.25
# differential_evolution step 21: f(x)= 2159.25
# differential_evolution step 22: f(x)= 2158.91
# differential_evolution step 23: f(x)= 2158.91
# differential_evolution step 24: f(x)= 2158.2
# differential_evolution step 25: f(x)= 2155.03
# differential_evolution step 26: f(x)= 2155.03
# differential_evolution step 27: f(x)= 2155.03
# differential_evolution step 28: f(x)= 2155.03
# differential_evolution step 29: f(x)= 2155.03
# Solution vector of current run:
# [ 1.54960363  1.69706131  0.45915759 -0.56546992]
# The run took:
# 00:05:24
# Parameters for run 16:
# [ 0.55291516  0.77788632  0.41951471 -0.52808739]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.6145079999999914
# differential_evolution step 1: f(x)= 2549.65
# differential_evolution step 2: f(x)= 2549.65
# differential_evolution step 3: f(x)= 2549.65
# differential_evolution step 4: f(x)= 2549.65
# differential_evolution step 5: f(x)= 2549.65
# differential_evolution step 6: f(x)= 2547.52
# differential_evolution step 7: f(x)= 2547.52
# differential_evolution step 8: f(x)= 2541.01
# differential_evolution step 9: f(x)= 2536.87
# differential_evolution step 10: f(x)= 2536.66
# differential_evolution step 11: f(x)= 2536.66
# differential_evolution step 12: f(x)= 2531.14
# differential_evolution step 13: f(x)= 2531.14
# differential_evolution step 14: f(x)= 2530.98
# differential_evolution step 15: f(x)= 2530.44
# Solution vector of current run:
# [ 0.70912153  0.73953859  0.35485207 -0.02649509]
# The run took:
# 00:02:52
# Parameters for run 17:
# [-1.68334762  0.52178365  0.30334582  0.8528245 ]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.16584800000000005
# differential_evolution step 1: f(x)= -1807.59
# differential_evolution step 2: f(x)= -1807.59
# differential_evolution step 3: f(x)= -1807.59
# differential_evolution step 4: f(x)= -1842.62
# differential_evolution step 5: f(x)= -1886.63
# differential_evolution step 6: f(x)= -1886.63
# differential_evolution step 7: f(x)= -1886.63
# differential_evolution step 8: f(x)= -1886.63
# differential_evolution step 9: f(x)= -1886.63
# differential_evolution step 10: f(x)= -1904.41
# differential_evolution step 11: f(x)= -1904.41
# differential_evolution step 12: f(x)= -1904.41
# differential_evolution step 13: f(x)= -1926.4
# differential_evolution step 14: f(x)= -1934.27
# differential_evolution step 15: f(x)= -1945.29
# differential_evolution step 16: f(x)= -1945.29
# differential_evolution step 17: f(x)= -1946.74
# differential_evolution step 18: f(x)= -1954.66
# differential_evolution step 19: f(x)= -1958.74
# differential_evolution step 20: f(x)= -1958.74
# differential_evolution step 21: f(x)= -1978.92
# differential_evolution step 22: f(x)= -1979.76
# differential_evolution step 23: f(x)= -1979.76
# differential_evolution step 24: f(x)= -1979.76
# differential_evolution step 25: f(x)= -1980.64
# differential_evolution step 26: f(x)= -1980.64
# differential_evolution step 27: f(x)= -1980.64
# differential_evolution step 28: f(x)= -1980.64
# differential_evolution step 29: f(x)= -1981.14
# differential_evolution step 30: f(x)= -1981.14
# differential_evolution step 31: f(x)= -1982.71
# differential_evolution step 32: f(x)= -1983.23
# Solution vector of current run:
# [-1.99448087  0.50031827  0.30788036  0.58048554]
# The run took:
# 00:04:51
# Parameters for run 18:
# [ 0.73294441  0.61486412  0.35644056 -0.7652979 ]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.3696843999999988
# differential_evolution step 1: f(x)= 1261.88
# differential_evolution step 2: f(x)= 1247.45
# differential_evolution step 3: f(x)= 1192.1
# differential_evolution step 4: f(x)= 1141.58
# differential_evolution step 5: f(x)= 1141.58
# differential_evolution step 6: f(x)= 1109.5
# differential_evolution step 7: f(x)= 1088.74
# differential_evolution step 8: f(x)= 1010.24
# differential_evolution step 9: f(x)= 1010.24
# differential_evolution step 10: f(x)= 1010.24
# differential_evolution step 11: f(x)= 1010.24
# differential_evolution step 12: f(x)= 1010.24
# differential_evolution step 13: f(x)= 988.711
# differential_evolution step 14: f(x)= 988.711
# differential_evolution step 15: f(x)= 965.084
# differential_evolution step 16: f(x)= 965.084
# differential_evolution step 17: f(x)= 965.084
# differential_evolution step 18: f(x)= 965.084
# differential_evolution step 19: f(x)= 965.084
# differential_evolution step 20: f(x)= 961.446
# differential_evolution step 21: f(x)= 961.446
# differential_evolution step 22: f(x)= 961.446
# differential_evolution step 23: f(x)= 961.446
# differential_evolution step 24: f(x)= 961.446
# differential_evolution step 25: f(x)= 960.955
# differential_evolution step 26: f(x)= 960.955
# differential_evolution step 27: f(x)= 960.955
# differential_evolution step 28: f(x)= 960.955
# differential_evolution step 29: f(x)= 960.955
# differential_evolution step 30: f(x)= 960.955
# differential_evolution step 31: f(x)= 960.85
# differential_evolution step 32: f(x)= 960.85
# Solution vector of current run:
# [ 1.90732446  0.63536515  0.37308359 -0.99977906]
# The run took:
# 00:05:12
# Parameters for run 19:
# [1.31242807 0.57229489 0.42926873 0.24903832]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.30252719999999983
# differential_evolution step 1: f(x)= 246.308
# differential_evolution step 2: f(x)= 223.059
# differential_evolution step 3: f(x)= 189.166
# differential_evolution step 4: f(x)= 189.166
# differential_evolution step 5: f(x)= 189.166
# differential_evolution step 6: f(x)= 34.9815
# differential_evolution step 7: f(x)= 34.9815
# differential_evolution step 8: f(x)= 34.9815
# differential_evolution step 9: f(x)= 34.9815
# differential_evolution step 10: f(x)= -26.2106
# differential_evolution step 11: f(x)= -26.2106
# differential_evolution step 12: f(x)= -26.2106
# differential_evolution step 13: f(x)= -41.1461
# differential_evolution step 14: f(x)= -41.1461
# differential_evolution step 15: f(x)= -41.1461
# differential_evolution step 16: f(x)= -41.1461
# differential_evolution step 17: f(x)= -45.8185
# differential_evolution step 18: f(x)= -45.8185
# differential_evolution step 19: f(x)= -51.0665
# differential_evolution step 20: f(x)= -51.0665
# differential_evolution step 21: f(x)= -51.0665
# differential_evolution step 22: f(x)= -51.0665
# differential_evolution step 23: f(x)= -51.5422
# differential_evolution step 24: f(x)= -51.5422
# differential_evolution step 25: f(x)= -51.6423
# differential_evolution step 26: f(x)= -51.6423
# differential_evolution step 27: f(x)= -51.6423
# differential_evolution step 28: f(x)= -52.9491
# differential_evolution step 29: f(x)= -52.9491
# differential_evolution step 30: f(x)= -53.49
# differential_evolution step 31: f(x)= -53.49
# differential_evolution step 32: f(x)= -54.3646
# differential_evolution step 33: f(x)= -54.3646
# differential_evolution step 34: f(x)= -54.9672
# differential_evolution step 35: f(x)= -54.9672
# differential_evolution step 36: f(x)= -54.9722
# differential_evolution step 37: f(x)= -54.9722
# differential_evolution step 38: f(x)= -55.2719
# differential_evolution step 39: f(x)= -55.7978
# differential_evolution step 40: f(x)= -55.7978
# differential_evolution step 41: f(x)= -55.9111
# differential_evolution step 42: f(x)= -55.9111
# differential_evolution step 43: f(x)= -55.9111
# differential_evolution step 44: f(x)= -56.1079
# differential_evolution step 45: f(x)= -56.1079
# differential_evolution step 46: f(x)= -56.1079
# differential_evolution step 47: f(x)= -56.1079
# differential_evolution step 48: f(x)= -56.1079
# differential_evolution step 49: f(x)= -56.1428
# differential_evolution step 50: f(x)= -56.2777
# differential_evolution step 51: f(x)= -56.2777
# differential_evolution step 52: f(x)= -56.2777
# differential_evolution step 53: f(x)= -56.2777
# differential_evolution step 54: f(x)= -56.2777
# differential_evolution step 55: f(x)= -56.2777
# differential_evolution step 56: f(x)= -56.2777
# differential_evolution step 57: f(x)= -56.2777
# Solution vector of current run:
# [ 1.89266767  0.58251762  0.42312967 -0.99997347]
# The run took:
# 00:08:25
# Parameters for run 20:
# [1.84267138 1.18539745 0.64965099 0.44640713]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.4571351999999971
# differential_evolution step 1: f(x)= 100.884
# differential_evolution step 2: f(x)= 100.884
# differential_evolution step 3: f(x)= 78.2242
# differential_evolution step 4: f(x)= 32.9569
# differential_evolution step 5: f(x)= 32.9569
# differential_evolution step 6: f(x)= 32.9569
# differential_evolution step 7: f(x)= -1.77335
# differential_evolution step 8: f(x)= -7.52435
# differential_evolution step 9: f(x)= -42.2529
# differential_evolution step 10: f(x)= -42.2529
# differential_evolution step 11: f(x)= -75.1968
# differential_evolution step 12: f(x)= -75.1968
# differential_evolution step 13: f(x)= -75.1968
# differential_evolution step 14: f(x)= -75.1968
# differential_evolution step 15: f(x)= -110.494
# differential_evolution step 16: f(x)= -110.494
# differential_evolution step 17: f(x)= -112.053
# differential_evolution step 18: f(x)= -112.053
# differential_evolution step 19: f(x)= -112.053
# differential_evolution step 20: f(x)= -112.053
# differential_evolution step 21: f(x)= -112.053
# differential_evolution step 22: f(x)= -112.053
# differential_evolution step 23: f(x)= -112.101
# differential_evolution step 24: f(x)= -117.185
# differential_evolution step 25: f(x)= -118.528
# differential_evolution step 26: f(x)= -118.528
# differential_evolution step 27: f(x)= -118.528
# differential_evolution step 28: f(x)= -118.528
# differential_evolution step 29: f(x)= -118.528
# differential_evolution step 30: f(x)= -119.523
# differential_evolution step 31: f(x)= -120.304
# differential_evolution step 32: f(x)= -120.997
# differential_evolution step 33: f(x)= -120.997
# differential_evolution step 34: f(x)= -120.997
# differential_evolution step 35: f(x)= -120.997
# differential_evolution step 36: f(x)= -120.997
# differential_evolution step 37: f(x)= -120.997
# differential_evolution step 38: f(x)= -120.997
# differential_evolution step 39: f(x)= -120.997
# differential_evolution step 40: f(x)= -122.066
# differential_evolution step 41: f(x)= -122.066
# differential_evolution step 42: f(x)= -122.066
# differential_evolution step 43: f(x)= -122.066
# differential_evolution step 44: f(x)= -122.966
# differential_evolution step 45: f(x)= -122.966
# differential_evolution step 46: f(x)= -122.966
# differential_evolution step 47: f(x)= -122.966
# differential_evolution step 48: f(x)= -122.989
# differential_evolution step 49: f(x)= -123.458
# differential_evolution step 50: f(x)= -123.553
# differential_evolution step 51: f(x)= -123.553
# differential_evolution step 52: f(x)= -123.553
# differential_evolution step 53: f(x)= -123.553
# differential_evolution step 54: f(x)= -123.639
# differential_evolution step 55: f(x)= -123.639
# differential_evolution step 56: f(x)= -123.639
# differential_evolution step 57: f(x)= -123.748
# differential_evolution step 58: f(x)= -123.79
# differential_evolution step 59: f(x)= -123.79
# differential_evolution step 60: f(x)= -123.79
# differential_evolution step 61: f(x)= -123.79
# differential_evolution step 62: f(x)= -123.79
# differential_evolution step 63: f(x)= -123.79
# differential_evolution step 64: f(x)= -123.79
# differential_evolution step 65: f(x)= -123.799
# differential_evolution step 66: f(x)= -123.829
# differential_evolution step 67: f(x)= -123.829
# differential_evolution step 68: f(x)= -123.837
# differential_evolution step 69: f(x)= -123.837
# differential_evolution step 70: f(x)= -123.838
# differential_evolution step 71: f(x)= -123.838
# Solution vector of current run:
# [ 1.99998352  1.18115046  0.65164787 -0.99998279]
# The run took:
# 00:10:59
# Parameters for run 21:
# [-1.02072566  0.74257054  0.45170919 -0.30372008]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.45207879999999734
# differential_evolution step 1: f(x)= 1236.52
# differential_evolution step 2: f(x)= 1236.52
# differential_evolution step 3: f(x)= 1213.66
# differential_evolution step 4: f(x)= 1200.21
# differential_evolution step 5: f(x)= 1200.21
# differential_evolution step 6: f(x)= 1200.21
# differential_evolution step 7: f(x)= 1200.21
# differential_evolution step 8: f(x)= 1200.21
# differential_evolution step 9: f(x)= 1199.17
# differential_evolution step 10: f(x)= 1199.17
# differential_evolution step 11: f(x)= 1199.17
# differential_evolution step 12: f(x)= 1196.26
# differential_evolution step 13: f(x)= 1184.42
# differential_evolution step 14: f(x)= 1183.57
# differential_evolution step 15: f(x)= 1180.25
# differential_evolution step 16: f(x)= 1180.25
# differential_evolution step 17: f(x)= 1180.25
# differential_evolution step 18: f(x)= 1180.25
# differential_evolution step 19: f(x)= 1176.75
# differential_evolution step 20: f(x)= 1176.75
# differential_evolution step 21: f(x)= 1176.61
# differential_evolution step 22: f(x)= 1175.83
# differential_evolution step 23: f(x)= 1175.19
# differential_evolution step 24: f(x)= 1175.19
# differential_evolution step 25: f(x)= 1175.19
# differential_evolution step 26: f(x)= 1175.19
# Solution vector of current run:
# [-1.17344829  0.71183446  0.44019082  0.99827756]
# The run took:
# 00:04:24
# Parameters for run 22:
# [-0.41362893  0.82526636  0.62692431 -0.1112585 ]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.6864767999999869
# differential_evolution step 1: f(x)= 3101.12
# differential_evolution step 2: f(x)= 2934.04
# differential_evolution step 3: f(x)= 2934.04
# differential_evolution step 4: f(x)= 2917.96
# differential_evolution step 5: f(x)= 2917.96
# differential_evolution step 6: f(x)= 2917.96
# differential_evolution step 7: f(x)= 2917.96
# differential_evolution step 8: f(x)= 2917.96
# differential_evolution step 9: f(x)= 2917.96
# differential_evolution step 10: f(x)= 2915.17
# differential_evolution step 11: f(x)= 2915.17
# differential_evolution step 12: f(x)= 2914.1
# differential_evolution step 13: f(x)= 2913.63
# Solution vector of current run:
# [-0.34038297  0.83782447  0.64426009 -0.55795856]
# The run took:
# 00:02:38
# Parameters for run 23:
# [-0.14492111  1.74168977  0.36988274  0.62641435]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 2.7474879999999344
# differential_evolution step 1: f(x)= 5990.08
# differential_evolution step 2: f(x)= 5990.08
# differential_evolution step 3: f(x)= 5944.26
# differential_evolution step 4: f(x)= 5899.05
# differential_evolution step 5: f(x)= 5859.54
# differential_evolution step 6: f(x)= 5859.54
# differential_evolution step 7: f(x)= 5859.54
# differential_evolution step 8: f(x)= 5859.54
# differential_evolution step 9: f(x)= 5859.54
# differential_evolution step 10: f(x)= 5859.54
# differential_evolution step 11: f(x)= 5859.54
# differential_evolution step 12: f(x)= 5859.54
# differential_evolution step 13: f(x)= 5859.54
# differential_evolution step 14: f(x)= 5859.54
# differential_evolution step 15: f(x)= 5854.55
# differential_evolution step 16: f(x)= 5854.55
# differential_evolution step 17: f(x)= 5854.55
# differential_evolution step 18: f(x)= 5854.55
# differential_evolution step 19: f(x)= 5854.37
# Solution vector of current run:
# [ 0.09185622  1.99129719  0.36815197 -0.77353152]
# The run took:
# 00:05:31
# Parameters for run 24:
# [0.91933839 1.22788543 0.5217802  0.15591921]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 1.0879375999999652
# differential_evolution step 1: f(x)= 2933.3
# differential_evolution step 2: f(x)= 2933.3
# differential_evolution step 3: f(x)= 2933.3
# differential_evolution step 4: f(x)= 2892.41
# differential_evolution step 5: f(x)= 2892.41
# differential_evolution step 6: f(x)= 2886.17
# differential_evolution step 7: f(x)= 2886.17
# differential_evolution step 8: f(x)= 2886.17
# differential_evolution step 9: f(x)= 2884.81
# differential_evolution step 10: f(x)= 2884.81
# differential_evolution step 11: f(x)= 2884.81
# differential_evolution step 12: f(x)= 2884.81
# differential_evolution step 13: f(x)= 2884.81
# Solution vector of current run:
# [1.20772396 1.02057076 0.40864927 0.32135229]
# The run took:
# 00:03:08
# Parameters for run 25:
# [-0.30997735  1.92415537  0.53331073 -0.00507011]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 3.3348815999999397
# differential_evolution step 1: f(x)= 6546.98
# differential_evolution step 2: f(x)= 6495.14
# differential_evolution step 3: f(x)= 6458.25
# differential_evolution step 4: f(x)= 6458.25
# differential_evolution step 5: f(x)= 6416.34
# differential_evolution step 6: f(x)= 6413.59
# differential_evolution step 7: f(x)= 6412.49
# differential_evolution step 8: f(x)= 6405.89
# differential_evolution step 9: f(x)= 6405.04
# differential_evolution step 10: f(x)= 6401.35
# Solution vector of current run:
# [-0.50296171  1.73148279  0.56573125 -0.00628901]
# The run took:
# 00:04:42
# Parameters for run 26:
# [-1.81169269  1.26586459  0.47414501 -0.77551433]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.6606795999999926
# differential_evolution step 1: f(x)= 926.191
# differential_evolution step 2: f(x)= 926.191
# differential_evolution step 3: f(x)= 903.461
# differential_evolution step 4: f(x)= 903.461
# differential_evolution step 5: f(x)= 902.336
# differential_evolution step 6: f(x)= 902.336
# differential_evolution step 7: f(x)= 902.336
# differential_evolution step 8: f(x)= 901.337
# differential_evolution step 9: f(x)= 892.875
# differential_evolution step 10: f(x)= 892.875
# differential_evolution step 11: f(x)= 892.854
# differential_evolution step 12: f(x)= 889.079
# differential_evolution step 13: f(x)= 889.079
# differential_evolution step 14: f(x)= 889.079
# differential_evolution step 15: f(x)= 889.073
# differential_evolution step 16: f(x)= 889.073
# differential_evolution step 17: f(x)= 889.073
# Solution vector of current run:
# [-1.73599344  1.0528293   0.52173692  0.25091372]
# The run took:
# 00:03:16
# Parameters for run 27:
# [0.51108895 0.96001501 0.60116229 0.31841014]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.783739999999982
# differential_evolution step 1: f(x)= 2991.48
# differential_evolution step 2: f(x)= 2929.35
# differential_evolution step 3: f(x)= 2872.19
# differential_evolution step 4: f(x)= 2852.88
# differential_evolution step 5: f(x)= 2852.88
# differential_evolution step 6: f(x)= 2842.12
# differential_evolution step 7: f(x)= 2842.12
# differential_evolution step 8: f(x)= 2842.12
# differential_evolution step 9: f(x)= 2842.12
# differential_evolution step 10: f(x)= 2835.73
# differential_evolution step 11: f(x)= 2835.73
# differential_evolution step 12: f(x)= 2835.73
# differential_evolution step 13: f(x)= 2834.69
# differential_evolution step 14: f(x)= 2833.85
# Solution vector of current run:
# [0.85690429 0.7641569  0.51996777 0.97849645]
# The run took:
# 00:03:08
# Parameters for run 28:
# [-1.24163755  0.79661828  0.32529235 -0.28194614]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 0.361716399999998
# differential_evolution step 1: f(x)= 357.319
# differential_evolution step 2: f(x)= 357.319
# differential_evolution step 3: f(x)= 342.735
# differential_evolution step 4: f(x)= 320.377
# differential_evolution step 5: f(x)= 262.83
# differential_evolution step 6: f(x)= 262.83
# differential_evolution step 7: f(x)= 262.83
# differential_evolution step 8: f(x)= 262.83
# differential_evolution step 9: f(x)= 262.83
# differential_evolution step 10: f(x)= 258.887
# differential_evolution step 11: f(x)= 258.887
# differential_evolution step 12: f(x)= 258.887
# differential_evolution step 13: f(x)= 258.887
# differential_evolution step 14: f(x)= 256.774
# differential_evolution step 15: f(x)= 255.763
# differential_evolution step 16: f(x)= 252.028
# differential_evolution step 17: f(x)= 252.028
# differential_evolution step 18: f(x)= 252.028
# differential_evolution step 19: f(x)= 252.028
# differential_evolution step 20: f(x)= 249.717
# differential_evolution step 21: f(x)= 249.717
# differential_evolution step 22: f(x)= 244
# differential_evolution step 23: f(x)= 244
# differential_evolution step 24: f(x)= 244
# differential_evolution step 25: f(x)= 244
# differential_evolution step 26: f(x)= 244
# differential_evolution step 27: f(x)= 244
# differential_evolution step 28: f(x)= 244
# differential_evolution step 29: f(x)= 244
# differential_evolution step 30: f(x)= 244
# differential_evolution step 31: f(x)= 244
# differential_evolution step 32: f(x)= 244
# differential_evolution step 33: f(x)= 244
# differential_evolution step 34: f(x)= 244
# differential_evolution step 35: f(x)= 243.887
# differential_evolution step 36: f(x)= 243.887
# differential_evolution step 37: f(x)= 243.887
# differential_evolution step 38: f(x)= 243.887
# differential_evolution step 39: f(x)= 243.12
# differential_evolution step 40: f(x)= 243.12
# differential_evolution step 41: f(x)= 242.941
# differential_evolution step 42: f(x)= 242.36
# differential_evolution step 43: f(x)= 242.36
# differential_evolution step 44: f(x)= 242.36
# differential_evolution step 45: f(x)= 242.36
# differential_evolution step 46: f(x)= 242.354
# differential_evolution step 47: f(x)= 242.354
# differential_evolution step 48: f(x)= 242.354
# differential_evolution step 49: f(x)= 242.295
# differential_evolution step 50: f(x)= 242.295
# differential_evolution step 51: f(x)= 242.295
# differential_evolution step 52: f(x)= 242.295
# differential_evolution step 53: f(x)= 242.295
# differential_evolution step 54: f(x)= 242.295
# differential_evolution step 55: f(x)= 242.295
# differential_evolution step 56: f(x)= 242.295
# differential_evolution step 57: f(x)= 242.199
# differential_evolution step 58: f(x)= 242.191
# differential_evolution step 59: f(x)= 242.141
# differential_evolution step 60: f(x)= 242.141
# differential_evolution step 61: f(x)= 242.141
# differential_evolution step 62: f(x)= 242.141
# differential_evolution step 63: f(x)= 242.127
# differential_evolution step 64: f(x)= 242.127
# differential_evolution step 65: f(x)= 242.127
# differential_evolution step 66: f(x)= 242.123
# Solution vector of current run:
# [-1.00690103  0.64651935  0.35294759  0.99993081]
# The run took:
# 00:09:49
# Parameters for run 29:
# [ 0.25596512  1.93228959  0.6287384  -0.45800377]
# 0  datapoints sampled
# 1000  datapoints sampled
# 2000  datapoints sampled
# Mean rt for current run:
# 2.93310879999995
# differential_evolution step 1: f(x)= 5839.79
# differential_evolution step 2: f(x)= 5782.1
# differential_evolution step 3: f(x)= 5782.1
# differential_evolution step 4: f(x)= 5782.1
# differential_evolution step 5: f(x)= 5720.56
# differential_evolution step 6: f(x)= 5683.76
# differential_evolution step 7: f(x)= 5651.5
# differential_evolution step 8: f(x)= 5651.5
# differential_evolution step 9: f(x)= 5649.31
# differential_evolution step 10: f(x)= 5644.7
# differential_evolution step 11: f(x)= 5644.7

# %%
# Read in results
optim_results = pd.read_csv(mle_out_path + '/mle_results_2.csv')

# %%
plt.scatter(optim_results['v_sim'], optim_results['v_mle'], c = optim_results['w_sim'])

# %%
# Regression for v
reg = LinearRegression().fit(np.expand_dims(optim_results['v_mle'], 1), np.expand_dims(optim_results['v_sim'], 1))
reg.score(np.expand_dims(optim_results['v_mle'], 1), np.expand_dims(optim_results['v_sim'], 1))
# Out:
# 0.617887802768772

# %%
plt.scatter(optim_results['dw_sim'], optim_results['dw_mle'], c = optim_results['w_sim'])

# %%
# Regression for a
reg = LinearRegression().fit(np.expand_dims(optim_results['a_mle'], 1), np.expand_dims(optim_results['a_sim'], 1))
reg.score(np.expand_dims(optim_results['a_mle'], 1), np.expand_dims(optim_results['a_sim'], 1))
# Out:
# 0.9278981038056895

# %%
plt.scatter(optim_results['sdv_sim'], optim_results['sdv_mle'])

# %%
# Regression for w
reg = LinearRegression().fit(np.expand_dims(optim_results['w_mle'], 1), np.expand_dims(optim_results['w_sim'], 1))
reg.score(np.expand_dims(optim_results['w_mle'], 1), np.expand_dims(optim_results['w_sim'], 1))
# Out:
# 0.8762772986396704

# %%
plt.scatter(optim_results['w_sim'], optim_results['w_mle'])

# %%
# Regression for c1
reg = LinearRegression().fit(np.expand_dims(optim_results['theta_mle'], 1), np.expand_dims(optim_results['theta_sim'], 1))
reg.score(np.expand_dims(optim_results['theta_mle'], 1), np.expand_dims(optim_results['theta_sim'], 1))
# Out:
# 0.8890366364460973

# %%
plt.scatter(optim_results['a_sim'], optim_results['a_mle'], c = optim_results['a_mle'])

# %%
# Regression for w
reg = LinearRegression().fit(np.expand_dims(optim_results['c2_mle'], 1), np.expand_dims(optim_results['c2_sim'], 1))
reg.score(np.expand_dims(optim_results['c2_mle'], 1), np.expand_dims(optim_results['c2_sim'], 1))
